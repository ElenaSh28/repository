# %% [markdown]
# # Тема: Влияние эпохи на лексику и темы в произведениях русской классической литературы

# %% [markdown]
# ### Постановка задачи
# - **Целевая аудитория**: литературоведы, историки, преподаватели русской литературы.
# - **Цель**: анализировать, как менялась лексика и тематическое наполнение произведений русской классики в разные исторические периоды.

# %% [markdown]
# ### Аналитика
# - Исследовать существующие работы по истории русской литературы, лингвистические исследования о развитии русского языка, а также проекты, связанные с текстовым анализом литературных произведений.

# %% [markdown]
# Исследования и работы по истории русской литературы охватывают широкий спектр тем и периодов, от древнейшей литературы до современности. Например, исследования охватывают историю литературы конца XIX - начала XX века, включая библиографические указатели с тысячами записей, освещающих развитие литературы, критики, журналистики и цензуры за этот период https://archive.org/details/istoriya_russkoy_literatury_XIX_XX.

# %% [markdown]
# 1. **Препроцессинг текста на русском языке**: Важным аспектом обработки текста является препроцессинг, который включает в себя лемматизацию и удаление стоп-слов. Этот процесс позволяет улучшить качество последующего анализа, избегая искажений, вызванных формами слов и их грамматическими характеристиками. Один из примеров обработки текста на русском языке демонстрируется на примере работы с текстом "Яблони цветут" Зинаиды Гиппиус, где проводится лемматизация и анализ текста с помощью spaCy https://melaniewalsh.github.io/Intro-Cultural-Analytics/05-Text-Analysis/Multilingual/Russian/01-Preprocessing-Russian.html.
#
# 2. **Анализ тональности на русском языке**: Проект на GitHub, посвященный анализу тональности текстов на русском языке, использует предварительно обученные трансформеры, такие как Multilingual BERT и Multilingual Universal Sentence Encoder, для классификации тональности. В исследовании были использованы различные наборы данных, включая RuReviews и RuSentiment, что позволило достичь значительных результатов в анализе тональности русскоязычных текстов https://github.com/sismetanin/sentiment-analysis-in-russian.
#
# Эти ресурсы и проекты иллюстрируют применение современных методов обработки естественного языка и машинного обучения для анализа русскоязычных литературных текстов и могут служить основой для дальнейших исследований в этой области. Использование Python и доступных библиотек NLP, таких как spaCy, NLTK, и предварительно обученных моделей, открывает новые возможности для глубокого понимания текстовых данных и извлечения значимой информации из литературных произведений.

# %% [markdown]
# ### Сбор данных
# - **Источники данных**: произведения из открытых электронных библиотек (https://limbook.net/book/anna-karenina.html)
# - **Корпус текстов**: выбранные произведения "Храбрые беглецы" Александра Куприна и "Анна Каренина" Льва Толстого
# - **Предобработка**: выполнить токенизацию, лемматизацию, удаление стоп-слов.
#
# ### Лингвистический компонент
# - Применить тематическое моделирование для выявления основных тем в произведениях каждой эпохи.
# - Использовать анализ частотности слов и выявление ключевых слов для изучения изменения лексики.
#
#
#
# ### Использование технических навыков
# - **Сбор данных**: написать скрипт для автоматического скачивания текстов произведений.
# - **Предобработка**: использовать библиотеки Python, такие как NLTK или spaCy, для лемматизации и токенизации текстов.
# - **Анализ**: применить библиотеку Gensim для тематического моделирования и создания частотных списков слов.

# %% [markdown]
# Для начала реализации проекта необходимо собрать и подготовить данные. Давайте начнем с этапа сбора данных: выберем и скачаем несколько произведений русских классиков из открытых источников. Затем мы сможем перейти к предобработке текста.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
import string
import warnings
warnings.filterwarnings("ignore")

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

with open('stop-ru.txt', 'r', encoding='utf-8') as file:
    stop_ru = file.read().split("\n")

def preprocess_text(text, stop_ru, language='russian'):
    # Удаление пунктуации
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Токенизация
    tokens = word_tokenize(text.lower(), language=language)

    # Удаление стоп-слов
    stop_words = set(stopwords.words(language)+ stop_ru)
    tokens = [word for word in tokens if word not in stop_words]

    # Лемматизация
    stemmer = SnowballStemmer(language)
    tokens = [stemmer.stem(word) for word in tokens]

    return tokens
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\elena\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\elena\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\elena\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
with open('krabriye-begletsy-Kuprin.txt', 'r', encoding='utf-8') as file:
    kuprin_text = file.read()

# Загрузка текста произведения "Анна Каренина" Льва Толстого
with open('anna-karenina-Tolstoy.txt', 'r', encoding='utf-8') as file:
    tolstoy_text = file.read()


kuprin_tokens = preprocess_text(kuprin_text, stop_ru)
tolstoy_tokens = preprocess_text(tolstoy_text, stop_ru)

# %%
kuprin_tokens[:10]
# Out:
# ['куприн',
#  'александр',
#  'иванович',
#  'александр',
#  'иванович',
#  'куприн',
#  'куприн',
#  'александр',
#  'иванович',
#  'храбр']

# %%
tolstoy_tokens[:10]
# Out:
# ['лев',
#  'николаевич',
#  'толст',
#  'ан',
#  'каренин',
#  'лев',
#  'толст',
#  'ан',
#  'каренин',
#  'широк']

# %%
from gensim.corpora.dictionary import Dictionary


corpus = [kuprin_tokens, tolstoy_tokens]
dictionary = Dictionary(corpus)

# Преобразование документов в векторы
corpus = [dictionary.doc2bow(doc) for doc in corpus]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def plot_wordcloud(tokens):
    text = ' '.join(tokens)
    wordcloud = WordCloud(
        background_color='white',
        width=1600,
        height=800,
        max_font_size=200,
        colormap='viridis'
    ).generate(text)

    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")  # Скрываем оси
    plt.show()
plot_wordcloud(kuprin_tokens)  # Для Куприна

# %%
plot_wordcloud(tolstoy_tokens)  # Для Толстого

# %% [markdown]
# Облако слов — это визуальное представление частотности слов в тексте, где размер слова коррелирует с его частотой появления в тексте. Этот вид визуализации помогает быстро оценить ключевую лексику и темы в произведениях.
#
# Облако слов для Куприна демонстрирует слова, такие как "мальчик", "мальчишка","товарищ", "дети", "разбойники", что может указывать на детскую тематику произведения, подчеркивая наивный и простодушный взгляд на мир, характерный для детского восприятия.
#
# Второе облако слов, относится к "Анне Карениной" Толстого и включает слова "мысли", "душа", "чувство", "разговор","жена", "муж", "княгиня", отражая социальные и семейные отношения, а также моральные и личные дилеммы, которые являются центральными для романа.

# %% [markdown]
# Найдем гапаксы в произведениях "Анна Каренина" и "Храбрые беглецы":

# %%
import re

def hapax_function(file_name):
    with open(file_name, encoding='utf-8') as file:
        list_of_words = re.findall('\w+', file.read().lower())
    
    freqs = {key: 0 for key in list_of_words}
    
    for word in list_of_words:
        freqs[word] += 1

    for word in freqs:
        if freqs[word] == 1:
            print(word)

hapax_function('anna-karenina-Tolstoy.txt')
# Out:
# вседневностью
# необычайная
# раскованность
# повествования
# сочетались
# цельностью
# мыслитель
# неоспоримо
# истощимых
# проявлениях
# маститый
# гончаров
# достоевскому
# неслыханная
# поравняться
# представит
# психологическую
# разработку
# небывалый
# реализм
# изображения
# оценку
# статей
# посвященных
# величайшим
# социальным
# завершенности
# редактора
# журнала
# каткова
# оглавлении
# объявлении
# обосновать
# жанра
# ссылкой
# эпические
# целостным
# самобытная
# эпопея
# национального
# самосознания
# устоях
# потребностях
# искусствах
# обычаях
# отечественной
# изобразить
# целостный
# рабство
# наполнял
# написана
# мироощущение
# пореформенной
# раздробленный
# лишенный
# единства
# руководителя
# хаосе
# целостность
# раздробленность
# проза
# всеобщим
# поэтической
# низменным
# историческое
# социальное
# философское
# обоснование
# отсутствует
# самобытное
# современном
# прозаически
# упорядоченную
# выступает
# целостного
# сравнению
# самобытной
# эпопеей
# проникать
# завязка
# развязка
# разрушении
# приходит
# выводит
# лирических
# отступлений
# злободневными
# политическими
# известиями
# извещают
# толкуют
# битве
# последующие
# охладевал
# завладевал
# признался
# современное
# проникнуться
# изображении
# вседневность
# толстовского
# вначале
# углублялся
# сажусь
# перехожу
# разрастается
# громадным
# выяснилось
# встречена
# эпилог
# шлагбаум
# воскресения
# осуждению
# отлучению
# лидер
# реакционной
# журналистики
# острую
# критическую
# стремился
# нейтрализовать
# высказался
# облегчил
# тревогой
# ругают
# тянут
# ноту
# действительные
# статские
# советники
# воплощенное
# крестьянского
# пробуждало
# чуют
# неподкупный
# упадку
# древняя
# приближающихся
# коренных
# нарастает
# творчестве
# приближения
# характерные
# кризисной
# метафоры
# высказываниях
# красносельские
# конь
# обмолвилась
# знаменательными
# зрелище
# напоминавшее
# римских
# ристалищах
# цирках
# метафоре
# относятся
# львице
# афинские
# посещает
# цельная
# современности
# характерно
# мыслителей
# древней
# империи
# неотвязчивой
# современностью
# пугает
# ввиду
# ужасающих
# олицетворилось
# глубокое
# сообщениями
# описаниями
# происшествий
# мания
# тучей
# пронеслась
# отбрасывает
# грозную
# грань
# стреляется
# неудачно
# прячет
# тайне
# библиотеки
# кончает
# товарного
# самоубийцы
# восклицания
# навели
# сопоставить
# революцию
# ознаменовавшим
# идеи
# революционеров
# народников
# социальная
# поклянется
# активных
# проповедовать
# апостолы
# проповедовали
# исповедников
# возвещать
# весть
# умирали
# идеям
# размышляет
# беседуя
# прохоровской
# мануфактуры
# буржуазный
# социалистический
# неизбежное
# связан
# эпохой
# отражается
# излюбленных
# толстовских
# творчества
# глубокой
# переоценки
# ценностей
# боровшиеся
# шестидесятники
# уничтожения
# задумывались
# сложатся
# пореформенные
# ограничиваясь
# расчисткой
# крепостничество
# укоренилось
# уживается
# стяжания
# устои
# непрочными
# семидесятническое
# уловил
# переходного
# формул
# изобилующего
# нравственными
# формулами
# смутной
# тревоге
# формула
# лаконичная
# многозначная
# тематическое
# закономерности
# художественную
# формулу
# композицию
# перевала
# современным
# приобретало
# обобщенный
# техническим
# новшеством
# переворотившим
# полудня
# усадебный
# расходящимися
# стальных
# земные
# всеобщая
# разобщенность
# вокзальной
# апокалипсиса
# источники
# отравила
# идиот
# сеть
# распространившихся
# звездой
# странник
# почве
# цивилизованных
# кочевников
# московском
# добровольцем
# стихией
# заслоняет
# судьбой
# гибель
# предзнаменованием
# разыскать
# предвещала
# путешественницей
# мечется
# петербургом
# москвой
# возлюбленного
# обирает
# потерявшей
# жалкой
# виноватой
# восклицает
# неумолимо
# надвигающегося
# заключала
# романист
# художественными
# возможностями
# постоянным
# разрушилась
# заполняя
# суетой
# образовавшуюся
# душевную
# пустоту
# рассеяния
# человечность
# машинальность
# согласовалась
# законами
# регулярным
# переломов
# катастроф
# вряд
# остротой
# переворотившейся
# объясняет
# рюрикович
# королей
# взаимный
# баланс
# наследственной
# праздной
# раздавил
# происшествия
# страдая
# сцепщик
# разоренного
# владения
# пустившийся
# путях
# обратном
# уносила
# разлучала
# подавляла
# раздирала
# глубокая
# символическая
# реальность
# ворвавшегося
# расположился
# выпроводил
# отправляясь
# высадят
# распоряжается
# принадлежащей
# заканчивалась
# эпизода
# воплощена
# зимней
# сливается
# мощной
# ощутил
# вечные
# завершая
# хроника
# актуальна
# задач
# текущем
# современная
# предчувствую
# разрушением
# построенного
# традициях
# преемственности
# распадом
# устоев
# разрушается
# весталкой
# хранительницей
# венчания
# нелепым
# основан
# идее
# придерживается
# достаточный
# сталкивается
# противодействием
# актуальный
# жизненный
# веяние
# сюжетный
# поднятом
# частно
# умирающей
# рисует
# явным
# недосягаемую
# налаженного
# уважающих
# основание
# сосредоточенным
# потеряны
# 370
# захватывает
# стремится
# получается
# сохранена
# утраченным
# ощутимым
# доставало
# посвящает
# ергушеве
# беспомощные
# усадьба
# проблемы
# переходил
# проблеме
# частной
# занятого
# распорядительность
# упадок
# запустение
# наследственное
# романтические
# социальные
# исторические
# ергушева
# совпадает
# землевладении
# проницательных
# энгельгардт
# раскрывалось
# конкретное
# формулы
# точнее
# целом
# разрушителем
# сенокосе
# присматривается
# ивану
# разравнивал
# отаптывал
# гармонию
# обретает
# исканий
# трагедию
# критическое
# рельефно
# рисуется
# глубоком
# положительных
# положительные
# идеалы
# логика
# героями
# ответственности
# грозный
# притчу
# иллюстрацию
# библейскому
# изречению
# современный
# фатальность
# умны
# разрешается
# далеких
# определяющей
# лишениями
# 555
# эпиграфа
# сердечна
# невиновных
# чернью
# приготовившей
# лукавой
# судит
# иной
# лермонтова
# прокурором
# летописцем
# пропустившим
# возмездия
# выраженная
# эпиграфе
# отнесена
# сурового
# бытописателя
# прейдеши
# ключом
# системе
# розгу
# брюзгливого
# наставника
# карательную
# определения
# пушкинский
# фабульная
# завершенность
# творческая
# концепция
# материала
# сюжетных
# линий
# возникал
# преодоления
# схем
# условностей
# вымышленным
# возбуждала
# завязкой
# развязкой
# фабуле
# 377
# определяются
# закономерностями
# взятой
# историческом
# своеобразии
# неотделима
# сумевшего
# равной
# освещены
# цельность
# определенности
# пропитывает
# свободном
# нарушив
# строку
# шиллера
# заботился
# произведении
# излюбленный
# long
# halein
# читателя
# привлекал
# просторную
# вместительную
# раму
# входило
# бывшею
# француженкою
# самими
# домочадцами
# сожительстве
# потерянные
# поссорилась
# экономкой
# приискать
# сафьянном
# выхоленное
# щекой
# американское
# дармштадт
# стеклянных
# выразишь
# полосу
# пробившуюся
# суконных
# стор
# отыскал
# шитые
# обделанные
# золотистый
# сафьян
# девятилетней
# сморщил
# собственная
# огромною
# грушей
# открывшею
# хлопотливая
# недалекая
# уличены
# постыдном
# оскорбиться
# физиологию
# улыбнулось
# потоком
# уверять
# тридцатичетырехлетний
# влюбчивый
# умерших
# годом
# догадывается
# истощенная
# состарившаяся
# некрасивая
# снисходительна
# возиться
# тривиальное
# roland
# аяяй
# неразрешимые
# потребностями
# подкладке
# вдоволь
# забрав
# грудной
# вывернутых
# носивших
# припасами
# бритья
# подождав
# жакетки
# понапрасну
# пошутить
# догадкой
# перевранные
# глянцевитую
# расчищавшую
# кудрявыми
# примирению
# прикажут
# умыт
# расчесан
# поскрипывающими
# телеграммой
# уставился
# матреша
# сходите
# авось
# мучаются
# навынтараты
# сдувая
# хомутом
# очевидным
# холеное
# одевшись
# прыснул
# рассовал
# цепочками
# брелоками
# встряхнув
# покупавшего
# подмешивался
# денежный
# придвинул
# перелистовал
# отметок
# отодвинув
# сырую
# газету34
# крайнюю
# политика
# избирал
# жившему
# развивающейся
# зрелости
# предпочитал
# консервативному
# разумным
# перестроить
# принуждала
# подразумевала
# узда
# молебна
# высокопарные
# любившему
# озадачить
# породой
# рюрике
# родоначальника
# руководящую
# объяснялось
# вопль
# радикализм
# угрожает
# поглотить
# консервативные
# элементы
# обязано
# подавления
# гидры
# гидре
# упорстве
# финансовую
# бентаме
# подпускались
# быстротою
# отравлялось
# неблагополучно
# висбаден35
# особы
# иронического
# стряхнул
# крошки
# радостную
# пищеварение
# дверьми
# везли
# уронили
# подбирай
# бегают
# кликнул
# шкатулку
# представлявшую
# повисла
# распространявшийся
# бакенбард
# наклоненного
# разняла
# водя
# шейке
# здоровавшемуся
# бабушке
# танчурочка
# гладя
# коробочку
# помадную
# плечико
# корни
# полчасика
# докладывать
# откушать
# капитанша
# калинина
# невозможном
# бестолковом
# усадил
# четким
# капитаншу
# тоскливое
# возбуждающею
# пепельницу
# пришпиленными
# осунувшимся
# худым
# выдававшимися
# худобы
# разбросанных
# шифоньеркой
# пытаясь
# осрамить
# отомстить
# малою
# отвыкнуть
# успевала
# отбирала
# шифоньерки
# потерянность
# втянул
# оглядела
# сияющую
# доброта
# хвалят
# сжался
# бледного
# нервного
# дрожанием
# физическою
# отчаянный
# рыдание
# горле
# захлопнула
# шифоньерку
# разуверил
# увлеченья
# поджались
# запрыгал
# пронзительнее
# пошатнулась
# опереться
# расширилось
# распухли
# налились
# накажи
# громкое
# погибли
# благодарностью
# спасу
# любовную
# благородства
# мерзки
# произносила
# выразившаяся
# испугала
# удивила
# сожаленье
# упавши
# прислушалась
# опоминалась
# вставши
# крике
# живите
# тихими
# постоял
# пятница
# часовщик
# аккуратном
# плешивом
# часовщике
# заведен
# заводить
# устрой
# явившемуся
# кушать
# провожавший
# захлопывая
# дверку
# отступая
# успокоив
# убежище
# обступали
# терпевших
# поваром
# исхудавшие
# спускавшимися
# костлявых
# видает
# останемся
# изготовит
# вчерашнему
# евши
# погрузилась
# потопила
# способностям
# ленив
# шалун
# небольшие
# чины
# нестарые
# почетное
# присутствий
# принадлежало
# сотню
# двоюродных
# достаточное
# расстроены
# раздаватели
# земных
# благ
# аренд
# концессий
# отказываться
# обижаться
# чрезвычайного
# сверстники
# нрав
# бровях
# белизне
# действовавшее
# встречавшихся
# ага
# присутственных
# заслужившие
# состояли
# основанной
# вычитал
# звания
# служения
# провожаемый
# писцы
# служащие
# членам
# простоты
# фамильярно
# либеральным
# пензенского
# закладывая
# бумагу
# слушании
# чтении
# прерываясь
# отворились
# зерцала
# обрадовавшись
# развлечению
# изгнал
# стеклянную
# прочтено
# потянувшись
# служака
# плут
# фомин
# участвовавших
# сторожа
# упроса
# широкоплечего
# курчавою
# бараньей
# стертым
# сходивших
# приостановившись
# бегущего
# лестницей
# шитого
# воротника
# вбегавшего
# дружескою
# побрезгал
# вертепе
# довольствуясь
# пожатием
# застенчиво
# самолюбивую
# озлобленную
# повлек
# опасностями
# министрами
# адъютантами
# постыдными
# уменьшать
# подчиненными
# шампанскому
# избравшими
# различные
# приезжавшим
# торопливый
# стесненный
# стесненностью
# выпустив
# элегантного
# загибавшимися
# запонками
# поглощали
# станиславич
# обратившись
# гимнаст
# поднимающий
# скотовод
# одноутробному
# забавляться
# заикнулся
# coterie36
# деньжонки37
# взяток
# незаслуженного
# присутствовавших
# оспаривал
# эге
# фазе
# консервативной
# портного
# фаза
# стыдясь
# детском
# гурину
# беседовать
# фамильярною
# почтительностью
# секретарям
# отодвинул
# захар
# никитич
# сконфуженный
# секретарем
# насмешливое
# доставая
# выходки
# бумажным
# двенадцатилетней
# зоологическом
# энергический
# жалуетесь
# университет
# шербацким
# женскую
# среду
# покрывавшею
# возвышенные
# трем
# барышням
# попеременкам
# фортепиано
# студенты
# литературы
# рисованья
# танцев
# барышни
# атласных
# шубках
# полудлинной
# статные
# золотою
# таинственном
# совершавшегося
# старшую
# поступив
# моряки
# балтийском
# щербацкими
# редки
# богатому
# бедному
# вероятиям
# земное
# низменное
# достойным
# чаду
# видаясь
# основывалось
# невыгодная
# почтенный
# занимающийся
# разведением
# стрелянием
# постройками
# бездарный
# делающий
# годившиеся
# выдающегося
# взрослого
# преградой
# красавцем
# влюблений
# решением
# харькова
# философскому
# материалистов
# полемикой
# уступки
# материалистам
# столковаться
# познакомив
# желтый
# человечек
# узким
# развитием
# естествознания
# сближал
# научных
# выводов
# животного39
# рефлексах
# биологии
# социологии
# связывали
# задушевными
# отдалялись
# углублялись
# подразделений
# оговорок
# цитат
# ссылок
# изяществом
# дикции
# кейсом
# вытекало
# основное
# специального
# передачи
# припасов40
# ответят
# коль
# отходят
# уничтожены
# существования
# умственною
# перерыва
# вопрошателя
# бурлака
# односторонностью
# простую
# естественную
# указываю
# различать
# покровительственный
# неделенное
# частями
# управы
# промолвил
# пересаливаем
# утешаемся
# европейскому
# выработали
# смеемся
# родной
# одноутробный
# вращавшийся
# поссорившийся
# прокофий
# трубину
# пресс
# папье
# родным
# любезных
# братцев
# несчастном
# поссорит
# снисходительнее
# подлостью
# бьющееся
# зоологического
# дорожкой
# ваньки
# кишел
# расчищенным
# дорожкам
# домиками
# князьками
# кудрявые
# обвисшие
# разубраны
# молчи
# спускаемых
# поднимаемых
# салазок
# грохотали
# катившиеся
# салазки
# катавшихся
# охватившим
# катка
# розан
# крапиве
# освещалось
# озарявшая
# недоступною
# щеголявшие
# учившиеся
# креслами
# робкими
# неловкими
# гигиенических
# избранными
# счастливцами
# обгоняли
# погодой
# двоюродный
# коньками
# коньков
# приближалось
# угле
# тупо
# поставив
# пригибавшийся
# обгонял
# висевшей
# снурке
# толчок
# упругою
# щербацкому
# ухватившись
# кивнула
# прекраснее
# белокурой
# поставленной
# статных
# детскость
# неожиданность
# кротких
# спокойных
# правдивых
# переносившая
# волшебный
# смягченным
# выпавший
# стряхивая
# ручкой
# инея
# упавшие
# муфту
# катался
# катальщик
# навинчивая
# каблук
# выступавшую
# шершавому
# укорачивая
# направляя
# бег
# опираетесь
# утратило
# ласковость
# означавшую
# гладком
# вспухла
# морщинка
# фальшивые
# растем
# стареем
# tiny
# bear41
# барышнях
# ласковости
# странностях
# зимою
# подчиняет
# поддастся
# возмутиться
# домику
# молясь
# разбегаясь
# выписывая
# конькобежцев
# папироской
# кофейной
# громыхая
# штуку
# убейтесь
# приступки
# разбежался
# дотронувшись
# кокетство
# уходившую
# встречавшую
# четверги
# огорчила
# теще
# тещей
# перестававший
# сказавший
# эрмитаж
# эрмитаже
# нехорошим
# означала
# безумна
# непохожим
# сочинял
# меню
# тюрбо43
# сияния
# липнувшим
# татарам
# салфетками
# нашедшимся
# встречавшим
# буфету
# закусил
# рыбкой
# раскрашенной
# ленточках
# завитушках
# конторкой
# составленная
# poudre
# riz
# vinaigre
# toilette
# обеспокоят
# липнувший
# белесый
# расходившимися
# почтения
# ухаживая
# расстелив
# бронзовым
# бра
# пододвинул
# бархатные
# карточкой
# опростается
# остендских
# свежи
# ла
# рюсс
# выберешь
# побегал
# недовольное
# поем
# десятка
# ростбифу
# каплунов
# консервов
# сос
# пулард
# лестрагон
# маседуан
# фрюи
# поднес
# каше
# блан
# марки
# устрицам
# столового
# нюи
# классический
# сыру
# пармезан
# блюдом
# перламутровых
# раковинах
# бутылкой
# смял
# накрахмаленную
# сдирая
# серебряною
# вилочкой
# перламутровой
# шлюпающих
# вскидывая
# татарина
# отвинтивший
# разливавший
# игристое
# разлатым
# рюмкам45
# выпивая
# трактире
# кабинетами
# беготни
# суетни
# бронз
# зеркал
# запачкать
# заинтересовали
# постарайся
# обстригаем
# засучиваем
# отпускают
# прицепляют
# запонок
# блюдечки
# диким
# дики
# отвлек
# шершавые
# спевку
# баниной
# дикость
# таврам47
# пересыпочку
# принимай
# догадываешься
# светящихся
# ошибаешься
# впиваясь
# гордится
# разделяются
# имеющая
# слабостей
# отталкивал
# откровенен
# удивительнейшая
# предвидения
# предсказала
# шаховская
# брентельна
# твоею
# слезам
# клеточке
# помигал
# завладела
# сближаемся
# невинным
# мою48
# трепещу
# проклинаю
# устроен
# молитве
# милосердию
# доливавшему
# бокалы
# вертевшемуся
# конкурентов
# перешло
# кирилла
# образцов
# рекрутский
# нежном
# догадываться
# шансы
# откинулся
# доливая
# поживаешь
# классически
# благословит
# тягу
# осквернено
# конкуренции
# предположениями
# вертится
# наевшись
# калач49
# удержишься
# bezwungen50
# meine
# irdische
# begier
# aber
# doch
# nicht
# gelungen
# hatt
# recht
# hubsch
# plaisir
# кроткое
# любящее
# расстаться
# делятся
# видал52
# крашеная
# конторки
# завитками
# гадины
# падшие
# евангельская
# перестань
# падшим
# гадин
# господин53
# перебрасывает
# правое
# затруднительные
# стареется
# подвернется
# красть
# калачей
# рассмеялся
# настаивает
# пробным
# камнем
# неплатоническую
# драме
# почтенье
# грехах
# слагалась
# цельных
# общественную
# слагается
# сблизить
# случающееся
# крайнее
# раздвоение
# адъютанта
# содержателе
# отдохновение
# счетом
# дополнением
# расплатился
# восьмнадцать
# танцующие
# явная
# разговорам
# будущности
# спорам
# привязанности
# несимпатичен
# утвердившись
# основанная
# полагала
# ездя
# непривлекателен
# влюбилась
# удовлетворял
# желаниям
# знатен
# блестящей
# военно
# обворожительный
# явно
# намерений
# сватовству
# тетки
# увидали
# ожидаемое
# обыкновенным
# передумано
# столкновений
# натальи
# вывозе
# переживались
# бoльшие
# щепетилен
# дочерям
# компрометирует
# приемах
# курсы55
# приседали
# осуждался
# безобразным
# внушали
# пятилетних
# заряженные
# пистолеты
# старшими
# ограничился
# ухаживанием
# нынешнею
# вскружить
# прошлой
# решатся
# посоветовавшись
# старуху
# сбиравшейся
# решавшейся
# поглощало
# прибавилось
# честности
# запутал
# окончанию
# оживленному
# мотивы
# бедняжке
# битвою
# порознь
# умершим
# лестна
# радостна
# вставала
# перспектива
# блестяще
# туманною
# взойдя
# обладании
# свободную
# бледности
# робкую
# пощаде
# умоляющего
# ласкающего
# склоняла
# приближавшееся
# отчаянное
# изобразился
# расстроенные
# четвергам
# желтая
# прекращает
# нервность
# утонченное
# грубому
# житейскому
# встречающееся
# дружелюбных
# оскорблены
# развратный
# желтую
# исправился
# испортились
# шуточно
# записываю
# каталась
# занимаетесь
# втягивается
# дураком
# растолкуйте
# калужской
# пропили
# хвалите
# просиявших
# отвернуться
# сопернике
# щемящею
# нетрудно
# сложенный
# брюнет
# обстриженных
# свежевыбритого
# иголочки
# изящно
# наклонясь
# спускавшего
# горожан
# согласились
# лаптями
# прожив
# сорренто
# вспоминается
# дружелюбный
# досказав
# имевшей
# неимения
# реальное
# воинскую
# выдвигать
# подразнить
# ежеминутно
# духах56
# верившая
# отыскиваю
# будущую
# субботу
# вертящиеся
# доказывают
# образованное
# порчу
# привороты
# домовых
# раздражившись
# угрожавшему
# допускаете
# допускаем
# найдено
# неизвестно
# приложении
# столики
# духи
# разбирают
# электричестве
# потрете
# смолу
# шерсть
# обнаруживается
# природное
# спиритов
# неудачная
# материальному
# медиум
# испытаем
# столиком
# несчастии
# обратится
# любезность
# недружелюбно
# расположенным
# отпустите
# колечко
# колечке
# вынесенное
# отвечавшей
# насупленными
# смотрящими
# навернулись
# светящуюся
# завлекла
# отравлено
# повторяющихся
# беличий
# срамите
# губите
# сватовством
# подлым
# дурацким
# предложении
# конченым
# вспылил
# выкрикивать
# заманиваете
# резонно
# зовите
# избранных
# тютьков
# тапера
# пляшут
# сводить
# вскружили
# девчонке
# франтик
# машине
# нуждается
# отдадим
# влюбится
# приседал
# катеньки
# заберет
# перепела
# щелкопер
# повеселиться
# заберешь
# вспомнишь
# дашенькой
# поцеловавшись
# неизвестностью
# роскошной
# светскою
# барышень
# тайная
# существовала
# невидимом
# интонаций
# влюбленные
# прикинул
# безика57
# игнатовым
# fleurs58
# куплеты
# cancan
# попавшееся
# ожидавший
# взошел
# отрекается
# встречаешь
# honni
# soit
# mal
# pense
# чопорное
# репутации
# консерватор
# приятности
# привязанным
# соединялся
# дивы
# сберу
# приятелем
# москвичах
# исключая
# дыбы
# сердятся
# служащему
# служитель
# обозначалось
# беганьем
# артельщиков
# жандармов
# подъездом
# встречающих
# виднелись
# полушубках
# валеных
# переходившие
# загибающихся
# дальних
# рельсах
# передвижение
# правдивая
# предпочитает
# знаться
# кларами
# вдали
# свистел
# кланяющимся
# обвязанным
# заиндевелым
# машинистом
# тендером
# медленнее
# потрясая
# багажом
# визжавшею
# остановкой
# пассажирские
# сходить
# нетерпеливые
# гвардейский
# вертлявый
# купчик
# сумкой
# разбудили
# внешне
# светского
# внешность
# принадлежность
# изяществу
# скромной
# миловидного
# ласковое
# перенеслись
# подходившую
# сдержанную
# оживленность
# порхала
# изгибавшею
# переполнял
# блеске
# диванчика
# просившемуся
# позови
# дождалась
# обхватила
# притянула
# filez
# parfait
# amour
# намекаете
# истощились
# объехала
# соскучилась
# помолчать
# улыбались
# сынок
# разлучалась
# ласковая
# относившаяся
# подхватывая
# старушечьи
# казенна
# порадовалась
# подставила
# выпрямилась
# волновавшеюся
# поданную
# особенному
# энергическому
# пожатию
# тряхнула
# носившею
# имеющем
# досадным
# лаврентий
# ехавший
# собачку
# артельщик
# задавило
# проходившими
# закутан
# отодвигаемого
# дворецкого
# обезображенный
# труп
# обертываясь
# певице
# догнавший
# передали
# обозначить
# назначаете
# вдове
# выходившие
# куска
# мгновенная
# удерживает
# отъехали
# предзнаменование
# надеемся
# мешавшее
# белоголовым
# пухлым
# похожим
# вертя
# державшуюся
# отнимала
# ручонка
# успокой
# давнишнюю
# закидывая
# убита
# поглощена
# grande
# обстоятельству
# злила
# измученном
# соболезнование
# мотая
# сияешь
# ровесница
# поднос
# отодвинула
# сочувственных
# энергическою
# пропало
# мука
# непритворные
# изволь
# женам
# подозревала
# понятиями
# уверенной
# любовнице
# раскаяньем
# раскаянью
# тронуть
# мучают
# виноватому
# невинному
# прошедшую
# перервали
# смягчалась
# отслужила
# умалчивали
# зажглись
# утешенье
# мук
# тружусь
# перевернулась
# мучь
# придумай
# отзывалось
# расстроена
# очаг
# презрении
# непроходимую
# божество
# повторится
# свесив
# успев
# прибытии
# отчужденность
# аркадьевну
# молодостью
# непохожа
# восьмилетнего
# походила
# двадцатилетнюю
# гибкости
# установившемуся
# выбивавшемуся
# притягивало
# недоступных
# крестя
# тетю
# меньшие
# прилипли
# отходили
# состоящей
# тети
# прислонился
# засиял
# бобрищевых
# никитиных
# межковых
# замечали
# последует
# стаскивала
# тереби
# растрепались
# выбившуюся
# слышите
# отрывая
# отправляя
# зовете
# покрывает
# анфиладу
# непоэтическую
# разболтал
# пристрастны
# рыцарь
# касающееся
# старушку
# недовольная
# повалила
# копошащихся
# визжащих
# заботьтесь
# сурок
# перевесить
# сумеет
# перепутает
# примиренье
# насмешлива
# прощен
# вечерняя
# беседа
# нарушена
# альбоме
# прощалась
# возвращалась
# кудрявому
# решительною
# приехавшем
# шевельнулось
# наклонив
# негромкий
# отказывавшегося
# приезжей
# затеваемого
# уставленную
# пудре
# залитую
# зал
# несся
# равномерный
# улье
# оправляли
# отчетливые
# скрипок
# начавшего
# штатский
# оправлявший
# височки
# изливавший
# незнакомою
# безбородый
# тютьками
# открытом
# жилете
# оправляя
# пробежав
# приглашая
# сторонился
# поглаживая
# балу
# тюлевом
# розовом
# тюле
# высокою
# розой
# листками
# завернувшуюся
# теснило
# спускалась
# кружевная
# берта
# смялись
# оторвались
# выгнутых
# каблуках
# ножку
# густые
# белокурых
# головке
# застегнулись
# порвавшись
# обвила
# медальона
# мраморность
# тюлево
# ленто
# кружевно
# цветной
# ожидавших
# стаивала
# бальной
# иерархии
# дирижер
# церемониймейстер
# егорушка
# банину
# протанцевал
# пустившихся
# дирижерам
# развязною
# занес
# опаздывать
# согнувши
# розовых
# задвигались
# скользкому
# отдыхаешь
# вальсируя
# пускаясь
# небыстрые
# precision
# разглядывать
# выезжающая
# сливаются
# затасканная
# балам
# наскучили
# обладала
# сгруппировался
# лысиной
# кривин
# смея
# отведите
# завальсировал
# умеряя
# перышко
# ажурных
# разнесло
# опахалом
# закрыло
# кривину
# открытую
# раскрасневшись
# кривина
# закруженная
# срезанном
# открывавшем
# округлые
# крошечною
# кистью
# обшито
# венецианским
# гипюром
# примеси
# гирлянда
# анютиных
# глазок
# ленте
# незаметна
# заметны
# украшая
# своевольные
# колечки
# курчавых
# выбивавшиеся
# точеной
# нитка
# жемчугу
# пышными
# рамка
# естественная
# изящная
# кучке
# поворотив
# покровительства
# заметное
# одобрительное
# туалету
# входите
# вернейших
# помощниц
# помогает
# волки
# танцую
# поклона
# вальсировавшую
# пригласит
# вальсировать
# барышню
# туров
# прерывистый
# корсунских
# описывал
# сорокалетних
# театре64
# затронул
# тревожило
# волшебным
# сновидением
# радостных
# скучных
# vis
# vis65
# пьяна
# возбуждаемого
# вспыхивающий
# изгибающую
# отчетливую
# помогая
# мучившемуся
# упустил
# наружно
# крикам
# бросающего
# rond
# chaine
# сжималось
# любованье
# опьянило
# вспыхивал
# изгибала
# делась
# беспечно
# сгибал
# пасть
# елецкой
# туманом
# пройденная
# строгая
# расставлять
# приглашена
# убитою
# воздушная
# юбка
# опущенная
# утонула
# складках
# розового
# тюника
# обмахивала
# вопреки
# бабочки
# уцепившейся
# травку
# готовой
# вспорхнув
# развернуть
# радужные
# танцуешь
# пригласить
# бегал
# распоряжаясь
# сталкивались
# парах
# свершилось
# твердом
# независимом
# поразившее
# потерянности
# передавалась
# задумывалась
# серьезен
# сверхъестественная
# браслетами
# ниткой
# жемчуга
# расстроившейся
# грациозные
# раздавленною
# столкнувшись
# корсунским
# кавалеров
# ответило
# бесовское
# забирая
# котильона
# bijou
# понемножку
# увлечь
# решительному
# неудержимый
# обжег
# вышедши
# гожусь
# бывавшего
# жаловаться
# прокофья
# видевшего
# оборванной
# презренный
# фонарю
# монах
# посты
# гадкими
# беспутный
# разгул
# обвинению
# причинении
# увечья
# шулером
# буйство
# выплатил
# материнского
# западный
# побои
# нанесенные
# старшине
# периоде
# набожности
# постов
# служб
# узды
# натуру
# поддержал
# дразнили
# монахом
# омерзением
# отвернулись
# неудержимым
# стесненным
# выскажу
# заставлю
# указанной
# адресе
# полуотворена
# полосе
# табаку
# покашливанье
# поведется
# шапкой
# шерстяном
# рукавчиков
# воротничков
# дери
# привилегированные
# прокашливаясь
# добудь
# поужинать
# поражающую
# дикостью
# сутуловатую
# худее
# огромнее
# висели
# исхудалом
# позабыто
# константином
# поворачиванье
# смягчила
# киева
# преследует
# полиция
# стоявшая
# двинулась
# неуменьем
# нескладностью
# крицкого
# вспоможения
# студентам
# школы69
# учителем
# установившееся
# унизишься
# порог
# обежали
# унижусь
# бруски
# завязанные
# приступаем
# производительная
# чахоточное
# трудились
# скотского
# досуг
# излишки
# отнимаются
# капиталистами
# наживаться
# выступивший
# костями
# устраиваем
# слесарную
# производство
# воздреме
# казанской
# селах
# слесарная
# аристократические
# употребляет
# спорю
# успокаиваясь
# самообманыванье
# сдвигая
# насыпанные
# потеряете
# медлительно
# слесарем
# девка
# заблуждениям
# подносом
# повеселев
# толкуй
# жадность
# женишься
# ванюшка
# конторщиком
# дернул
# классная
# переменяй
# женись
# заведи
# неправы
# внешним
# дружбой
# дорожит
# графинчику
# приставай
# прибью
# разврата
# учреждениями
# разделял
# путаницы
# цыганам
# цыган
# мешаться
# перескакивать
# одолевала
# кривого
# поднятым
# падающем
# ковровые
# подвязанными
# хвостами
# сбруе
# махрами
# укладывались
# приходе
# рядчика
# разъясняется
# закутавшись
# раздумывая
# распоряжениях
# пристяжную
# донскую
# надорванную
# лихую
# увлечься
# гадкою
# выпустит
# позволять
# исполнявшей
# экономки
# падал
# площадки
# разбуженный
# сонный
# босиком
# легавая
# сука
# сбив
# выскочила
# визжала
# терлась
# соскучился
# осветился
# внесенной
# оленьи
# рога
# отдушником
# отцовский
# сломанная
# пепельница
# недовольством
# попытками
# падениями
# далось
# слушаясь
# пудовые
# гимнастически
# сушилке
# сушилка
# выстроена
# придумана
# скрытым
# купленная
# взгляну
# скотная
# сугроба
# скотной
# навозным
# примерзшая
# зашевелились
# гладкая
# пегая
# широкая
# беркут
# губе
# гиппопотам
# обнюхивала
# паву
# шаткие
# замычала
# шершавым
# телка
# подталкивала
# пах
# хвостиком
# посвети
# мастью
# длинна
# пашиста
# гречу
# порядиться
# коровника
# семеном
# рядчиком
# планам
# умерли
# идеалом
# священным
# будущая
# повторением
# святого
# идеала
# общежитейских
# уселся
# сяду
# расстался
# болтала
# умерялось
# укладывалось
# просыпу
# возбужденных
# теплоте70
# тиндалю
# самодовольство
# ловкости
# опытов
# философского
# всплывала
# стаде
# беркутовых
# казовый
# уравнении
# величину
# инстинктом
# пегою
# коровой
# ы
# ь
# выхаживали
# переварившая
# бегавшая
# полаять
# внося
# подвизгивая
# поласкал
# пес
# чайку
# подсовывала
# свернулась
# высунувшуюся
# заднюю
# лапу
# почмокала
# липкие
# блаженном
# выезде
# перечтешь
# прислав
# непостоянны
# чутки
# прекратили
# тетей
# приготовлениями
# записывала
# спокойном
# прикрывает
# игрушечному
# мешочку
# батистовые
# подергивались
# высматривая
# нашлось
# хитрая
# смешливая
# откидываясь
# протянув
# оскорбилась
# сватать
# забудется
# разошлось
# густая
# занимавшую
# выговоренную
# опоздавший
# загораживал
# аннушкой
# огляделась
# спального
# устроилась
# отперла
# заперла
# закутав
# укутывала
# топке
# фонарик
# прицепила
# сумочки
# читалось
# возня
# ходьба
# прислушаться
# бивший
# левое
# налипавший
# закутанного
# развлекали
# тряска
# постукиваньем
# переходы
# мелькание
# читаемое
# перчатках
# прорвана
# отражением
# стаей
# дразнила
# ножичек
# усиливалась
# достигать
# баронетства
# откинулась
# перебрала
# влюбленное
# стеклу
# приложила
# гладкую
# поверхность
# беспричинно
# натягиваются
# завинчивающиеся
# колышки
# раскрываются
# движутся
# дыханье
# образы
# колеблющемся
# яркостью
# поражают
# шуба
# забытью
# втягивало
# теплого
# вошедший
# нанковом
# истопник
# термометр
# ворвались
# окутанного
# снятую
# подышать
# засвистал
# унести
# крылечке
# вагонами
# затишье
# вдыхала
# снежный
# рвалась
# свистела
# столбам
# столбы
# занесено
# заносилось
# затихала
# налетала
# порывами
# противостоять
# согнутая
# проскользнула
# стуки
# железу
# бурного
# занесенные
# пробегали
# обвязанные
# папирос
# надышаться
# заслонил
# колеблющийся
# козырьку
# наклонился
# почтительного
# сотен
# встречаемых
# неудержимая
# одолев
# затрепал
# железным
# оторванным
# прекрасен
# рассудком
# минутный
# сблизил
# испугана
# возобновилось
# порвется
# натянутое
# грезах
# наполняли
# жгучее
# возбуждающее
# бело
# обступили
# обратившее
# поразившие
# хрящи
# насмешливую
# упорный
# сознала
# сгорал
# медлительным
# пылкость
# устремив
# незнакомых
# непоколебимого
# самодовлеющ
# служащий
# окружном
# возненавидел
# заговаривал
# толкал
# гримасничал
# самообладание
# давлением
# непризнавания
# распущенные
# разбросанные
# собраны
# направлены
# блаженной
# бологове
# замирать
# носились
# поворотит
# взглянет
# связанное
# петербургски
# самоуверенною
# выдающеюся
# мучимый
# жаждою
# добравшийся
# источнике
# овцу
# свинью
# выпила
# взмутила
# ворочавшая
# тупыми
# оживляя
# подбежавшему
# проницательностью
# наклоняясь
# предоставляя
# просившегося
# мгновением
# рублем
# даря
# отпуска
# пролито
# коснулся
# понедельникам
# подчеркиваешь
# merci
# знаменитую
# горячилась
# смею
# советовать
# съездила
# примирением
# кружков
# кондратий
# встретившее
# повис
# разочарованье
# стройными
# ощущении
# простодушный
# доверчивый
# доложили
# нездорово
# желтым
# снесли
# оливковую
# ветвь
# решительна
# касавшимся
# интересовавшаяся
# уставать
# напрасного
# ломания
# копий
# развинчиваюсь
# сестричек
# религиозно
# патриотическое
# покорностью
# ухватились
# изуродовали
# обсуждают
# мелко
# роняют
# панславист
# козни
# соединения
# добродетель
# христианка
# христианству
# обещаясь
# дообеденное
# употребила
# присутствовать
# скопились
# привычных
# безупречною
# придавать
# подчиненный
# подвергнуться
# доверяется
# такту
# унизить
# рекомендованный
# добить
# звездами
# распределена
# успевать
# строжайшей
# аккуратности
# девизом
# степане
# аркадьиче
# рассчитывала
# раздосадована
# модистке
# переделки
# переделано
# модистка
# перекрестила
# вронскою
# извинять
# родства
# высказывании
# искреннего
# наделало
# овациях
# устанавливаться
# допив
# сливками
# читаешь
# улыбаются
# слабостям
# сделавшуюся
# поглощавшие
# служебные
# замечательным
# появлявшимся
# богословия
# твердые
# шекспире
# рафаэле
# бетховене
# распределены
# абажур
# выдаются
# обстригся
# дописывая
# брызгало
# потушенным
# припрятанным
# поручик
# знатный
# долгах
# попадавший
# гауптвахту
# начальством
# злодеев
# денщику
# шильтон
# лиловым
# атласом
# белокурым
# личиком
# канарейка
# парижским
# кофейника
# украшением
# баронессу
# камеровского
# умеете
# хорошенькие
# заслуги
# мойтесь
# убирайтесь
# заботливо
# винтик
# кофейнике
# прибавлю
# испортите
# испорчу
# женили
# пересыпая
# посоветуете
# неверна
# пошлые
# обвенчан
# стыдливою
# мужчине
# мужественным
# воздержным
# зарабатывать
# старомодных
# элегантным
# смелым
# всунул
# сварился
# обрызгал
# шуму
# залил
# умоетесь
# порядочного
# нечистоплотность
# советуете
# поближе
# поцелует
# зашумев
# платьем
# умывался
# описал
# кратких
# заплатит
# портной
# грозит
# скандалы
# прекратятся
# надоела
# редька
# genre
# рабыни
# ребекки
# беркошевым
# секундантов
# обстановке
# трехлетней
# беззаботной
# педаль
# обливал
# здоровую
# лора
# милеевым
# фертингофа
# бузулуков
# бузулуковым
# пропускает
# каски
# растираясь
# мохнатым
# полотенцем
# послом
# касках
# каской
# мигают
# кивают
# хмурятся
# бух
# груша
# фунта
# набрал
# закатывался
# являться
# явившись
# поздней
# происходил
# восстановления
# ослабевающих
# приближением
# рыбий
# жир
# лапис
# помогало
# приглашен
# естественнее
# остатком
# учились
# внимательного
# постукиванья
# растерянной
# ошеломленной
# вымыв
# покашливая
# поживший
# злился
# пустобрех
# применяя
# словаря
# знаменитому
# признаках
# баричу
# низменности
# рассыпать
# бисер
# растеряна
# решайте
# переговорю
# коллегой
# золотые
# каверн
# указания
# нервное
# прочее
# подозрении
# скрываются
# духовные
# яузский
# объезжать
# поездок
# поддерживало
# вредило
# соденскими
# удаление
# вызывающих
# повредят
# немецкие
# шарлатаны
# слушались
# больную
# воскликнула
# сопутствуемая
# исхудавшая
# перенесенного
# наполнились
# леченье
# смешною
# составление
# кусков
# разбитой
# вазы
# разбито
# пилюлями
# порошками
# присесть
# скучные
# обиделся
# научно
# княжны
# наставлением
# разрешая
# изложено
# шарлатанам
# приготовлениях
# заболевшую
# унизительны
# спайка
# непрочна
# надломилось
# испытанных
# пережитый
# решаете
# андреич
# проницательным
# сморщенного
# потянулась
# потрепал
# шиньоны
# доберешься
# ласкаешь
# дохлых
# козырь
# поделывает
# проснись
# морозцу
# смешалась
# растерялась
# уличенный
# преступник
# собраться
# напустилась
# укоризненную
# хмурилось
# гадких
# неблагородных
# молодчиков
# франта
# лечите
# возите
# шарлатанов
# смирилась
# шептала
# поцелуй
# засучив
# нападения
# дочерняя
# почтительность
# взрыва
# вернувшуюся
# запрещаю
# куколками
# vieux
# saxe
# убирали
# похолодело
# низеньком
# ближайшем
# устремившую
# дребезжащим
# соболезнованья
# зашевелила
# перехватывать
# горячность
# способна
# горячности
# наговорить
# соболезнует
# сожалений
# притворств
# мучаешь
# огорчена
# горячке
# сокрушаться
# мучить
# намеревалась
# отозвалось
# разразившегося
# обняли
# необходимая
# мазь
# общения
# сердцах
# бедную
# неизлечимое
# душевном
# недоуменье
# женихов
# называемых
# мерку
# бальном
# замялась
# гадком
# упрошу
# настояла
# скарлатину
# шестерых
# тесные
# служебный
# официальный
# разнообразным
# прихотливым
# разъединенных
# набожного
# уездном
# жмет
# центру
# правительственных
# внушения
# добродетельных
# набожных
# честолюбивых
# принадлежащих
# совестью
# кружком
# умевшая
# сживаться
# невыносим
# туалетов
# спуститься
# полусвета
# сходные
# держалась
# двоюродного
# стара
# сделаюсь
# богадельню
# предпочитала
# волнующую
# урожденная
# двоюродная
# загоралось
# затушить
# преследовать
# преследование
# раз75
# антракта
# ясновиденью
# находившая
# делось
# пойманы
# пойманным
# пойман
# entendons
# nous
# огоньки
# принявшись
# оглядывать
# становлюсь
# рисковал
# свободной
# приставшего
# положившего
# прелюбодеянье
# величественное
# игравшею
# мирил
# оскорбителем
# помирили
# антракт
# распознала
# хористки
# миротворства
# блаженны
# миротворцы
# спасутся
# нескромно
# фамилий
# угадывать
# позавтракавшие
# переводите
# выпившие
# обгоняет
# кивает
# останавливается
# взбегает
# верхний
# этаж
# губки
# прощальный
# выпивают
# прощальных
# расспрашивают
# мамзели
# отправляются
# написали
# страстное
# понятным
# уверяют
# рак
# выгоняет
# мирить
# титулярной
# советницы
# примирителем
# уверяю
# талейран
# извинились
# таять
# дипломатические
# таланты
# раскаиваются
# смягчается
# подвергается
# преследованиям
# грубостям
# дерзостям
# мерз
# примирять
# пускаю
# дипломацию
# горячится
# колбасики
# разливаюсь
# дипломатических
# тонкостях
# держания
# веера
# поднявшийся
# лиф
# голою
# рампе
# пропускавшего
# миротворстве
# забавляло
# замешан
# замешаны
# эскадроне
# жалобой
# оскорбили
# происходящее
# попавшемся
# лихаче
# погнались
# разболевшись
# пьяных
# вытолкал
# неблаговидность
# замять
# дорожащего
# потолковали
# кедрову
# титулярному
# советнику
# адъютантский
# вензель
# смягчению
# фойе
# неуспех
# затихавший
# разгорался
# полуслове
# ретировался
# скверная
# уморительная
# клер
# пудрой
# подъезжать
# огромному
# тучный
# читающий
# назидания
# прохожих
# стеклянною
# приезжавших
# освеженною
# освеженным
# пушистыми
# коврами
# освещенным
# блестевшим
# свеч
# белизною
# скатерти
# прозрачным
# прибора
# разместилось
# бархате
# перебиваемый
# предложениями
# каульбаха78
# прозванная
# enfant
# terrible
# обоими
# забавное
# изящного
# называемого
# small
# talk
# дипломату
# знавшему
# попробую
# теме
# дана
# вышивать
# говоруны
# прибегнуть
# изменяющему
# средству
# тушкевиче
# louis
# белокурого
# вкусе
# поддержался
# неизбежными
# темами
# последнею
# общественною
# злословие
# мальтищева
# шьет
# rose80
# осуждение
# несчастной
# мальтищевой
# разгоревшийся
# костер
# толстяк
# собиратель
# гравюр
# клубом
# подкрадываться
# спущусь
# майолики
# толкучке
# толку
# банкиры
# шюцбург
# сказывали
# тысячерублевых
# соусов
# единственна
# удивительна
# эффект
# производимый
# одинаков
# производимого
# эффекта
# остроумной
# связать
# воедино
# осуждали
# переменилась
# тени82
# кончают
# типун
# злы
# умом83
# стих
# оправдывалась
# отделав
# прусском
# короле
# злословили
# характеристику
# входную
# входившему
# спокойными
# сотый
# конца84
# шутливым
# рассказывайте
# приподнимался
# отличавшим
# отделяли
# наклонением
# протягиваемые
# засиделась
# миссионер
# индейскую
# перебитый
# замотался
# задуваемой
# топова
# антидилювиальные
# мода
# выводится
# браки
# разлетается
# браками
# называем
# перебесились
# искусственно
# прививать
# оспу
# помогло
# раскаяться
# пословицу
# снятою
# умов
# сердец
# наливала
# неблагородно
# альбомами
# произносить
# поощряла
# пылая
# жегшим
# заставляете
# виновною
# прощенья
# замигал
# принуждает
# напрягла
# счастливейшими
# несчастнейшими
# исчезну
# прогонять
# изменяйте
# неуклюжею
# усевшись
# неторопливым
# слышным
# обычном
# составе85
# музы
# sneering
# повинности87
# указ
# нападала
# шепнула
# удалившихся
# отвлечен
# точности
# понятия88
# доступны
# глянцевом
# кожане
# прозябшего
# серого
# взвивавшегося
# наружную
# крючка
# шубки
# нагнувши
# внутренним
# отцепила
# кружево
# прожгли
# ладонь
# достижению
# особого
# развернув
# заложенном
# папизме
# потирал
# встряхивал
# отгоняя
# случившимся
# сцепившиеся
# сложным
# затруднительным
# нелогичным
# проработал
# отражениями
# отстранялся
# прошедший
# пропастью
# увидавший
# разобран
# звучному
# освещенной
# отражался
# сделанном
# висевшем
# приятельниц
# безделушки
# паркете
# весило
# спальной
# унижающее
# убеждался
# совершали
# нападая
# малахитовым
# бюваром
# начатою
# впервые
# заглянуть
# переноситься
# фантазерством
# сваливается
# бессмысленная
# переносят
# делаться
# подлежит
# найден
# узаконений
# подлежало
# определяется
# обязанное
# ответственное
# домашнего
# суставах
# трещанье
# успокаивал
# аккуратность
# подъехавшей
# всходили
# скрещенные
# треснет
# речью
# башлыка
# пожара
# просыпаясь
# скинула
# башлык
# броню
# неестественного
# ложился
# сообщала
# глубина
# возвратившийся
# запертым
# найдется
# неосмотрительности
# легкомыслию
# непроницаемостью
# бесполезность
# загнул
# трещи
# удержав
# комическим
# воображаемою
# преступать
# безнаказанно
# произведено
# некрасиво
# отклонив
# бесполезным
# копаясь
# выкапываем
# кару
# опустилось
# возмутило
# определи
# покажутся
# неуместными
# вызваны
# заблуждением
# сжаты
# наполнялось
# носовой
# свиста
# переждав
# ровностью
# противопоставляла
# обуха
# добротою
# убеждением
# овладевал
# подшучиванья
# заменившее
# ужасною
# обворожительною
# удовлетворено
# опускала
# постыдную
# сгибалась
# падала
# унижаться
# обращала
# мольбу
# отвратительное
# заплачено
# наготою
# сообщался
# убийцы
# резать
# прятать
# убийством
# тащит
# режет
# покрывал
# сообщника
# прятала
# рассталась
# вступлением
# опошливать
# являлась
# безобразной
# наготе
# сновиденье
# посещало
# снилось
# расточали
# сновидение
# просыпалась
# единицу
# физику
# курсе
# порученное
# мечтавший
# чувствовавший
# созревшим
# единому
# быти
# наивному
# сознанные
# поступках
# стыдные
# затягивались
# невидными
# значительными
# неделей
# выдергиванье
# вылечит
# дружная
# весен
# радуются
# растения
# возбудила
# утвердила
# одинокую
# соблюдена
# феврале
# лечиться
# раздражая
# требовавшего
# климат
# почва
# выводились
# неудовлетворенное
# бродящих
# физике
# морозная
# таяло
# доходило
# наст
# возах
# пасха
# понесло
# лил
# четверг
# совершавшихся
# полились
# сдвинулись
# льдины
# вспенившиеся
# потоки
# горку
# барашками
# прояснело
# съело
# подернувший
# наполнивших
# испарений
# ожившей
# зазеленела
# вылезающая
# иглами
# надулись
# почки
# калины
# смородины
# липкой
# обсыпанной
# лозине
# загудела
# выставленная
# облетавшаяся
# залились
# невидимые
# жаворонки
# зеленей
# обледеневшим
# жнивьем
# заплакали
# чибисы
# налившимися
# бурою
# неубравшеюся
# низами
# болотами
# пролетели
# весенним
# гоготаньем
# журавли
# гуси
# заревела
# выгонах
# облезшая
# перелинявшая
# заиграли
# кривоногие
# ягнята
# теряющих
# волну
# блеющих
# матерей
# быстроногие
# просыхающим
# отпечатками
# босых
# тропинкам
# пруду
# холстами
# застучали
# дворам
# топоры
# налаживающих
# суконную
# липкую
# знающее
# разрастутся
# ветви
# заключенные
# почках
# примется
# перелинявшею
# гладкою
# пригревшись
# мычали
# выгнать
# пастух
# подбирая
# поневы
# загоревшими
# хворостинами
# мычавшими
# ошалевшими
# телятами
# загоняя
# приплод
# ранние
# телята
# мужицкую
# корову
# годовых
# корыто
# употребляемом
# сделанные
# плотником
# чинил
# масленицы
# перенесены
# земледельческие
# чинили
# скородить
# обшитом
# мерлушкой
# тулупчике
# ломая
# соломинку
# молотилке
# телячьего
# туркиным
# пролезут
# топко
# сеяли
# досаднее
# собственному
# соломы
# пятеро
# компот
# компост
# пересыпают
# семенной
# испортили
# амбарам
# испортился
# пересыпали
# лопатами
# амбар
# оторвав
# посева
# колодца
# обмывал
# оседлай
# седлали
# вертевшегося
# весенних
# возку
# отрыву
# продержать
# одобрять
# раздражающий
# унылый
# приказчиков
# перебывало
# предположениям
# стихийною
# успеете
# нанимались
# суры
# чефировку
# слабы
# прикупим
# похуже
# спите
# долом
# буланого
# подведенного
# проедете
# бойкою
# застоявшейся
# похрапывающей
# лужами
# попрашивающей
# житном
# дворах
# иноходи
# конька
# впивая
# проезде
# оставшемуся
# праховому
# осовывавшемуся
# расплывшими
# следами
# оживавшим
# коре
# мохом
# раскинулись
# ковром
# плешины
# вымочки
# лощинах
# запятнанные
# рассердили
# стригуна
# топтавших
# встретившемуся
# ипата
# вспахать
# обсадить
# полуденным
# линиям
# залеживался
# перерезать
# навозных
# запасных
# травосеянием
# выстроить
# вырыть
# пруд
# удобрения
# переносные
# загороды
# истощенной
# межами
# топтать
# рассевавшим
# рубеже
# пашне
# пшеничная
# озимь
# изрыта
# ископана
# меже
# раскуривая
# трубку
# смешаны
# размята
# слежалась
# смерзлась
# комьями
# отвесть
# рубеж
# затянет
# рассуждай
# заискивая
# пудовику
# лапте
# волочишь
# непросеянная
# разминаем
# набирая
# ладонях
# растирая
# непросеянной
# испытав
# пользою
# шагал
# налипавшей
# василья
# метку
# высевать
# запотел
# чур
# ругать
# употребленного
# отличится
# гляньте
# рассадил
# родному
# глянешь
# запомнят
# посеял
# сказывает
# ото
# ржей
# отличишь
# научили
# позалетошный
# пожертвовали
# посеяли
# растирай
# прошлогодний
# плугом
# яровую
# жнивью
# отжил
# зеленел
# посломанных
# ступицу
# чмокала
# вырываясь
# полуоттаявшей
# плужной
# держало
# оттаявших
# бороздах
# ступицы
# пахота
# превосходная
# бороновать
# сбыла
# вспугнул
# поворота
# лесного
# караульщика
# вальдшнепах
# расстроит
# весеннее
# акацию
# ямскую
# узнaю
# весенний
# вылезая
# комком
# переносице
# тяге
# постоять
# сумка
# переодеваться
# клевере
# расчесанный
# добрался
# состоят
# совершаешь
# фартучке
# монашеством
# стилем
# интересных
# новостей
# интересную
# новость
# набралось
# окружающим
# изливал
# основу
# понимающий
# польстившую
# проголодавшиеся
# закуске
# наелись
# полотка
# соленых
# обедам
# превосходным
# травник
# грибки
# крапивные
# курица
# крымское
# чудесно
# закуривая
# парохода
# тряски
# изучаем
# профан
# экономическим
# этнографическим
# пухлых
# травничок
# спускавшееся
# макуши
# сойдя
# парусинный
# чехол
# лакированного
# фасона
# чуявший
# отходил
# чулки
# прикажи
# продаешь
# повизгивая
# вилась
# лизала
# долгуша
# пройдем
# долгуше
# обвернул
# тигровым
# куришь
# сигара
# тужу
# отсыпной
# паек
# сотворен
# оссиановских89
# изучай
# математик
# искании
# речкой
# осиннике
# мшистой
# топкой
# освободившейся
# двойняшке
# березе
# развилине
# нижнего
# перепоясался
# седая
# ходившая
# насторожила
# рассыпанные
# осиннику
# рисовались
# висящими
# частого
# извилистыми
# узкими
# ручейками
# промежутках
# шевелившихся
# таянья
# двинувшийся
# грифельного
# мшистую
# прислушивающуюся
# расстилавшееся
# оголенных
# макуш
# подернутое
# тускневшее
# неспешно
# хлопотливее
# заухал
# филин
# переступила
# речки
# послышалась
# прокуковала
# захрипела
# нарушая
# заменившийся
# дымком
# щелкнули
# взводимые
# протяжное
# гуканье
# шаля
# ржал
# жеребенок
# заяц
# самец
# взводя
# охотнику
# третьим
# свистком
# хорканье
# кинул
# мутно
# сливающимися
# нежными
# побегами
# макушек
# летящая
# летела
# хорканья
# равномерное
# наддирание
# тугой
# приложился
# стрела
# взмыла
# шлепнулась
# топкую
# дыму
# кончиком
# пушистого
# хвоста
# продлить
# подносила
# убитую
# правого
# заряжая
# пронзительные
# следовавшие
# свистки
# свистя
# хоркая
# ласточки
# заворот
# серебряная
# западе
# березок
# переливался
# арктурус
# перестали
# летать
# колесница
# взволновать
# прозевают
# стегнул
# схватились
# летевший
# вальдшнеп
# сложил
# умница
# мгновенную
# сделавшегося
# сельские
# расчел
# лес90
# дровяной
# жителей
# уверенные
# грамоту
# счел
# счесть
# планет91
# купит
# чистыми
# рассрочку
# увлекаться
# стачки
# отступного
# барышники
# обтянутая
# запряженною
# гужами
# сытою
# подпоясанный
# служивший
# средних
# длиннополый
# синий
# пуговицами
# сморщенных
# щиколках
# прямых
# икрах
# надеты
# округло
# вытер
# приветствовал
# осмелился
# ослушаться
# сиятельства
# потешаться
# пройдите
# переговорите
# презрительным
# затруднений
# осмотрелся
# допуская
# повидаться
# ставивший
# оченно
# скупы
# укупишь
# торговал
# гласное
# судопроизводство
# кладут
# сведешь
# малость
# торговаться
# ястребиное
# хищное
# жесткое
# костлявыми
# расстегнул
# навыпуск
# перекрестившись
# торгует
# бумажником
# рощу
# условьице
# застегнув
# окованную
# кожаный
# фартук
# покупочкой
# оттопыренным
# карманом
# серий92
# нашедшее
# начат
# хмель
# падало
# пренебрегла
# продажа
# обходишься
# сливаться
# сморщился
# безвинно
# обижают
# расстраивают
# продают
# барски
# скупают
# арендатор
# поляк
# полцены
# чудесное
# плуту
# мизерное
# считанье
# глазунья
# яичница
# травничку
# чудесного
# похвaлите
# молчалив
# разделся
# облекся
# гофрированную
# ночную
# пустяках
# развертывая
# душистый
# мыла
# усовершенствование
# влажно
# театры
# зевал
# везде93
# зевоту
# масленые
# сонные
# шансов
# напролом
# зевнул
# челюстями
# хитрое
# дипломатическое
# увлеченье
# подействовали
# свежею
# полученною
# раной
# зажгло
# помогают
# вылез
# пронырством
# семей
# дарованье
# подличали
# нуждались
# дед
# даришь
# получишь
# родовым
# трудовым
# аристократы
# подачками
# груб
# объяснились
# полковые
# пренебрегал
# товарищества
# обязанным
# установившийся
# проговаривался
# попойках
# затыкал
# легкомысленных
# намекать
# городу
# догадывались
# завидовали
# завидовавших
# предполагали
# оборота
# обрушиться
# приготавливали
# бросят
# пожилых
# готовящимся
# скандалом
# блестящему
# понравившаяся
# говорившая
# одобрила
# вертеровская
# неожиданного
# меньшим
# разбирал
# танцовщицу
# снисходителен
# нравящаяся
# поведения
# препятствиями94
# записался
# кобылу
# предстоящими
# зависимое
# освежался
# волновавших
# красносельских
# равнялся
# положенным
# четырем
# пудам
# половинкою
# мучного
# расстегнутом
# жилетом
# заказанного
# бифстека
# входившими
# выходившими
# кузины
# тройкой
# горячем
# блюде
# придвинув
# молоденький
# пажеского
# браслетом
# заплывшими
# подкрепляешься
# молоденького
# гримасу
# хересу
# переложив
# молоденькому
# выбери
# рейнвейну
# отросшие
# усики
# офицерам
# погону
# баритоном
# поешь
# неразлучные
# острыми
# углами
# стегна
# красненский
# нумерова
# недурна
# кутила
# безнравственными
# необычайную
# бочка
# начальникам
# выпитое
# игроком
# сплетне
# скандале
# забава
# блеснув
# заправлять
# проиграть
# проиграю
# растянув
# командовании
# заставлявшим
# разгороженной
# надвое
# чухонской
# избе
# лагерях
# уткнувшегося
# взлохмаченного
# тащившего
# пробасил
# терещенко
# барину
# протирая
# закутываясь
# тигровое
# подаваемый
# тройка
# брянского
# надул
# брянский
# опоздай
# саврасый
# уходившему
# указательным
# врать
# бутылочки
# лежишь
# вспомню
# матраца
# запрятал
# смяв
# пуговиц
# квартира
# притоном
# царского
# захромал
# поскачете
# спасители
# денщик
# огурцом
# велит
# задали
# пришедших
# окончили
# волков
# залез
# крыше
# лимона
# заставляющая
# немножечко
# бутылочку
# пью
# потяжелеешь
# лимон
# обстриг
# лысине
# плешиветь
# надвинув
# временная
# конюшня
# балаган
# досок
# построена
# проездку
# поручил
# тренеру
# конюх
# грум
# тренера
# клочком
# неумелою
# жокеев
# растопыривая
# раскачиваясь
# фру96
# sir
# горла
# намордник
# локтями
# развинченною
# дворик
# бараком
# дежурный
# нарядный
# метлой
# бараке
# денникам
# пятивершковый
# рыжую
# крупную
# отворачивающегося
# раскрытого
# деннику
# ма
# грязным
# ногтем
# нервнее
# рluck
# потнения
# головою
# перестановка
# окошечка
# караковая
# оглядевшись
# стати
# статям
# безукоризненная
# костью
# грудина
# выдавалась
# свислый
# значительная
# косолапина
# крупны
# подпруге
# выдержке
# поджаром
# толще
# широки
# ребер
# сдавлена
# вытянута
# заставляющее
# сказывается
# английскому
# выступающие
# растянутой
# атлас
# коже
# крепкими
# расширялась
# храпа
# ноздри
# перепонкой
# механическое
# скашивая
# выпуклый
# белок
# налился
# упруго
# уговаривая
# остром
# перекинувшуюся
# гривы
# придвинулся
# летучей
# мыши
# ноздрям
# острое
# наморднике
# переставлять
# заду
# приливала
# кусаться
# милорд
# lord
# расстраивайтесь
# отъехал
# угрожавшая
# хлынул
# закрытой
# сердечные
# пристают
# обыкновенная
# пошлая
# жалуемся
# соединяя
# мучительность
# хитрить
# забывали
# повторявшиеся
# встряхнувшись
# скрыться
# непродолжительный
# вытягивавшего
# пристяжных
# выглянуло
# садов
# мокрым
# ветвей
# капала
# крыш
# дождю
# переезжал
# мостика
# садовника
# отопрут
# саблю
# песку
# дорожки
# обсаженной
# отлогим
# вопрошающим
# сговаривались
# осторожность
# недоумевающий
# силился
# чуткостью
# проявлению
# испытующее
# вопросительное
# стесняли
# мореплавателя
# видящего
# компасу
# движется
# расходится
# надлежащим
# удаляет
# должного
# отступлении
# компас
# отклонения
# ушедшего
# застигнутого
# чернокурчавую
# лейке
# перилах
# придерживала
# неожиданностью
# приблизиться
# подбежать
# балконную
# испугал
# видав
# скрытую
# перервав
# сорванным
# рабскую
# преданность
# подкупала
# разделяю
# прощу
# листком
# трясется
# удесятеренною
# находившего
# кризис
# неестественное
# сообщалось
# покорным
# соединена
# безвыходностью
# неискренно
# выступать
# покраснели
# наводить
# обсуждение
# поверхностностию
# уходила
# насмешливостью
# ударение
# предупреждал
# гражданском
# послушали
# добавила
# государственною
# точностью
# скандал
# злая
# мягким
# предпримет
# честною
# натурой
# рассуждала
# лживыми
# слушайся
# обещаешь
# обещай
# обещаю
# разорвано
# возвращающегося
# покрытые
# приблизив
# просидели
# растревожен
# стрелки
# циферблате
# переполнен
# указывающая
# задремавшему
# полюбовался
# переливающимися
# столбами
# толкачиков
# мошек
# конвойных
# выскочило
# поспеет
# вспыхивало
# охватывало
# въезжал
# атмосферу
# обгоняя
# переодевался
# прибегал
# торопливости
# баракам
# бараков
# окружавших
# кипящие
# барак
# белоногим
# оранжевой
# попоне
# кажущимися
# отороченными
# конюха
# седлают
# отворенном
# оседлана
# окинул
# дрожавшей
# оторвавшись
# зрелища
# барака
# беседкам
# ничьего
# кавалергарда
# гусара
# посылавших
# подходивших
# теснились
# кавалергардская
# громкими
# возгласами
# ожидаемого
# оканчивающий
# забрызганный
# кавалергард
# серому
# потемневшему
# дышавшему
# жеребцу
# жеребец
# тыкаясь
# укоротил
# кавалергардский
# проснувшийся
# избранной
# великосветской
# переговаривалась
# беседками
# встречавшиеся
# призваны
# призов
# эксельбантами
# пьяным
# пьяную
# улыбающийся
# неважном
# подлежат
# обсуждению
# нахмуренное
# побледнело
# выдающаяся
# дрожал
# отвечай
# расстраивайся
# остановило
# блистая
# лоснящимися
# измученные
# проваживаемые
# конюхами
# уводились
# английские
# капорах
# поддернутыми
# животами
# странных
# водили
# поджарую
# переступала
# эластичных
# бабках
# попону
# лопоухого
# чудесным
# сидевшими
# бабками
# середней
# указывали
# вынимания
# нумеров
# отправления
# серьезными
# строгими
# бледными
# достался
# скачущими
# медлителен
# парадный
# застегнутый
# тугие
# воротнички
# ботфорты
# важен
# лихорадке
# подпругу
# покосилась
# оскалилась
# проверяли
# седланье
# гальцин
# гнедого
# дававшегося
# гусар
# кот
# крупу
# англичанам
# кровной
# грабовского
# кобыле
# слабых
# нервов
# фронтовой
# лазаретная
# фура
# нашитым
# задерживайте
# посылайте
# отчаивайтесь
# двинуться
# стальное
# зазубренное
# сбитое
# скрипящее
# уравнял
# двойные
# гибкой
# запруженной
# галопа
# обогнал
# белоногом
# лопоухом
# соперником
# проскакал
# разгорячив
# тряскую
# рысь
# вскидывавшую
# скакало
# четырехверстном
# эллиптической
# косогор
# ирландская
# банкетка
# состоящая
# вала
# утыканного
# хворостом
# перепрыгнуть
# убиться
# канавы
# начинались
# сажень
# запруженная
# шириною
# перепрыгивать
# переезжать
# вброд
# чья
# заезжать
# пускания
# сестрин
# тронулись
# бинокли
# обращены
# пеструю
# кучку
# одинокие
# пешеходы
# перебегать
# собранная
# растянулась
# близятся
# поскакали
# доскакивая
# влегшую
# отбивавший
# несшая
# рекой
# перелетели
# летя
# барахтался
# дианой
# полетела
# дианы
# падающая
# кошка
# беспрепятственной
# саженей
# бежавшей
# отбивавших
# остававшихся
# барьера
# скрылись
# стукнуло
# разгоряченная
# шедшим
# барьером
# стукнула
# копытом
# расстояние
# круп
# неудаляющиеся
# движущиеся
# махотину
# начинавшее
# поравнялось
# скачков
# препятствием
# косогоре
# забрызганное
# отрывистое
# перейдены
# сап
# скок
# копыт
# прежнем
# усиливались
# успокоивать
# приберечь
# равный
# подскакивал
# ирландской
# банкетке
# банкетку
# мгновенное
# нерешимость
# хлыст
# неосновательно
# оттолкнувшись
# канаву
# такте
# канавка
# скока
# мокры
# острых
# лишком
# мягкости
# быстроты
# канавку
# поспев
# скверное
# непростительное
# скаку
# касался
# валилась
# затрепыхалась
# подстреленная
# сделанное
# сломало
# удалялся
# шатаясь
# грязной
# перегнув
# прелестным
# тянул
# забилась
# рыбка
# замоталась
# тянуть
# уткнув
# храп
# говорящим
# проигранная
# постыдная
# непростительная
# погубленная
# фельдшер
# невредим
# пристрелить
# соскочившей
# фуражки
# неисправимое
# фуражкой
# расстраиваемое
# усиленным
# зимним
# подозрениях
# теперешних
# отклонила
# пожар
# нa
# сгоришь
# безумия
# подтрунивающее
# выдумывал
# открывать
# делались
# кроткий
# смирный
# постоянная
# дача
# соседстве
# постоянных
# неудобство
# царское
# подозрений
# восьмилетней
# неверных
# обманутых
# безобразного
# пятнадцатому
# числу
# заведенному
# распространяться
# китае98
# дочитал
# просители
# доклады
# удаления
# наград
# пенсий
# будничное
# отнимавшее
# краткий
# выездов
# прожито
# дефицит
# находившийся
# приятельских
# постукал
# бесценный
# уменьшенным
# умственного
# огорчений
# слюдину
# откровенного
# слюдина
# подавал
# лайковой
# натянув
# натягивайте
# перервать
# натяните
# наляжьте
# натянутую
# усидчивости
# добросовестности
# давление
# постороннее
# спускаясь
# поданной
# расслышанное
# отнявшим
# прочитанной
# брошюрой
# глубиною
# широтою
# просвещенного
# путешественником
# будничные
# значительному
# свиданиях
# прикалывая
# бант
# ...
# физиономий
# самок
# самцов
# комнатных
# заслушались
# вызвали
# перерыве
# беспокоясь
# недослушанный
# освобожденный
# сорокамиллионный
# утренние
# всемирной
# руководило
# определенным
# придумываемых
# успокоениях
# живее
# поспевала
# выступавшие
# потемневшем
# недодумал
# разъяснится
# ограничивается
# христианскою
# откровению
# буддистов
# магометан
# исповедующих
# делающих
# полоскавшимся
# заслышав
# плавающего
# корячившего
# ножонки
# пухлого
# выжимала
# ванне
# призванная
# уперся
# ручками
# запрукал
# окатили
# окутали
# простыней
# вытерли
# пронзительного
# начинаешь
# привычном
# сюрприз
# распустится
# снимала
# просияла
# дуб
# захочешь
# стемнело
# вспыхивала
# гром
# падающим
# каплям
# проходящий
# разветвлением
# яркие
# потухала
# смущает
# явлены
# откровением
# соединяюсь
# волею
# неволею
# соединен
# евреи
# магометане
# конфуцианцы
# буддисты
# разнообразных
# проявлении
# непостижимое
# ветке
# планету
# вращения
# астрономы
# вычислить
# расстояниях
# весе
# возмущениях
# небесных
# тел
# основаны
# видимом
# светил
# передо
# астрономов
# видимого
# меридиану
# горизонту
# понимании
# христианством
# верованиях
# скрывшая
# радостен
# угловую
# невыразимая
# осчастливило
# просветило
# сюрприза
# засело
# молюсь
# властен
# вложить
# современность
# актуальности
# проблематики
# нашедшей
# датированные
# проводы
# даты
# хронологический
# проясняется
# трагедия
# хронология
# строилась
# календарной
# последовательности
# определенном
# самарском
# хивинском
# походе
# лане
# обреновиче
# добровольцах
# заметок
# синхронным
# дневников
# ссылался
# апрельской
# книжки
# фету
# рассказывается
# вносил
# испытано
# калинов
# автобиографично
# словно
# угадывала
# берс
# энергично
# мелке
# державшей
# софье
# андреевне
# изъяснить
# ломберную
# криптограмму
# обыкновенными
# буквами
# соне
# образована
# лёва
# лёв
# домашнем
# воспринималась
# транскрипции
# лёвине
# самарину
# прочтении
# удачно
# уникальна
# станкевича
# идеалист
# повесть
# станкевиче
# наследием
# нарисован
# идеалиста
# противостоящего
# новейшим
# веяниям
# факты
# преобразованной
# творческой
# отождествление
# прототипами
# романических
# именами
# марию
# тулубьева
# несла
# плотную
# изящную
# разглядывал
# арабские
# породистые
# сохранилась
# заметка
# навело
# подобном
# самоубийстве
# степановны
# пироговой
# узелком
# ближайшую
# ясенки
# изменены
# мотивировка
# сергеевич
# сухотин
# дворцовой
# конторы
# 1868
# мария
# алексеевна
# сухотина
# добилась
# ладыженского
# дружен
# алексеевны
# дьяковым
# материалом
# литературный
# источник
# греческому
# освоился
# гомером
# подлиннике
# каренон
# головной
# степановича
# перфильева
# 1878
# 1887
# троюродной
# прочитав
# цельного
# наклепал
# образе
# отозвалась
# воронцовых
# распространение
# раевский
# доброволец
# сражавшийся
# алексинац
# раевского
# упоминается
# легенд
# возникшая
# типического
# обобщения
# достигнутого
# заслуживает
# догадка
# стремоуховым
# докладе
# конференции
# венеции
# прообразом
# званий
# константинович
# стихам
# миллер
# бахметьевой
# покинула
# льву
# николаевичу
# родстве
# отголоски
# лирики
# воспроизвел
# существенные
# родного
# аскетичен
# прозвали
# перелом
# мотать
# религиозным
# проститутку
# выкупил
# нездоровая
# укоров
# сгубили
# щербатова
# лосиной
# прасковье
# сергеевне
# щербатовой
# неравнодушен
# описании
# московскому
# дворянскому
# погруженностью
# софью
# андреевну
# узнавали
# описанные
# списал
# софья
# плюс
# нестерпимый
# яснополянские
# собеседники
# бывшая
# бабушки
# пелагеи
# урожд
# горчаковой
# ключницей
# поручал
# заботам
# аристократки
# князей
# горчаковых
# самарским
# управляющих
# 1000
# опишет
# 2000
# прототипы
# офицерским
# четырехверстным
# конные
# состязания
# встречает
# высокопоставленных
# беседует
# наблюдает
# описаны
# оболенского
# борисовичем
# голицыным
# взятии
# упоминаются
# милютин
# назван
# махотиным
# сожалел
# ежели
# вымышленных
# действительными
# описывать
# действительное
# однородных
# создать
# воздание
# поколеблется
# уготованное
# второзаконие
# послании
# римлянам
# павла
# мстите
# возлюбленные
# гневу
# божию
# указываются
# 1895
# 1961
# страховым
# 1914
# алексеев
# 426
# 389
# гусев
# 374
# 375
# 575
# степняк
# кравчинский
# 1935
# 1957
# 421
# софьи
# алчевская
# передуманное
# пережитое
# 1912
# лермонтов
# ссылались
# понаслышке
# краевского
# орган
# чиновничества
# барометром
# упорной
# высказана
# пугливых
# охранителях
# мерещится
# гидра
# тысячах
# утреннего
# канцлер
# австро
# венгрии
# газетных
# хрониках
# курортный
# гассен
# нассау
# шайки
# coterie
# деньжонки
# распространенные
# радикальной
# демократической
# безотрадная
# земств
# спекуляции
# замечаемая
# интеллигентных
# акции
# облигации
# чеки
# закладные
# полисы
# варранты
# закрывают
# лапоть
# зипун
# развернулась
# страницах
# 1885
# напечатал
# разрабатывать
# психологию
# непосредственной
# психические
# акты
# совершающиеся
# рефлексов
# физиологическому
# исследованию
# 39
# животного
# чарльза
# 1882
# происхождение
# редакцией
# пространные
# 1896
# присылку
# дарвинизм
# натолкнул
# духовный
# кейс
# ло
# пародийные
# медвежонок
# меблированными
# номерами
# петровке
# репутацией
# 43
# особым
# приготовленная
# калкан
# ценившееся
# гурманами
# рисовой
# пудры
# туалетного
# 45
# разлатые
# плоские
# 47
# анакреон
# выжженным
# 49
# стебницкого
# лескова
# драматический
# нашумевшей
# пьесе
# чернявского
# гражданский
# сравнивалась
# воровством
# bezwungen
# куплет
# оперетты
# иоганна
# летучая
# мышь
# великолепно
# земную
# блаженство
# пушкинского
# чумы
# падшее
# созданье
# вальсингама
# 53
# герое
# диккенса
# мистере
# подснепе
# выработал
# отмахивался
# устранял
# краской
# возмущения
# диккенс
# 427
# 347
# симпозионе
# афродиты
# земная
# чувственная
# пандемос
# небесная
# чувственных
# урания
# небесной
# высшие
# герье
# 1837
# юридические
# литературные
# медицинские
# удобную
# приложения
# 56
# духах
# спиритизме
# медиумизм
# 1907
# медиумические
# бутлерова
# критику
# продолжил
# плодах
# 57
# безик
# besique
# карточная
# моду
# колоды
# 58
# увеселительное
# заведение
# устроенное
# парижского
# кафешантана
# антрепренер
# беккер
# петровском
# парке
# истолкует
# компетенции
# идеальная
# точность
# 64
# новшество
# освобождению
# столичных
# монополии
# столиц
# императорских
# соответствовал
# названию
# общедоступный
# недоступен
# революционеры
# рассматривали
# пален
# александру
# пропаганды
# контроль
# теплоте
# тиндаль
# физик
# рассматриваемая
# дюк
# вымышленное
# леконт
# пародийный
# герцога
# лиля
# саксонского
# фарфора
# кристиана
# 1921
# швеции
# дебютировала
# сценах
# 78
# необыкновенна
# вильгельм
# каульбах
# мюнхенской
# увенчанный
# лавровым
# венком
# идеализма
# монументальными
# помпезными
# композициями
# столпотворение
# вавилона
# расцвет
# классической
# греции
# иерусалима
# битва
# гуннов
# актеры
# оперные
# изучали
# скульпторов
# овладеть
# пластикой
# театрах
# пользовались
# сопоставление
# местом
# театральной
# критики
# озорницей
# 80
# rose
# гранжа
# тибу
# diables
# roses
# дьяволы
# крикливо
# 82
# необычайные
# приключения
# петера
# шлемиля
# принадлежит
# немецкому
# романтику
# адальберту
# шамиссо
# 1781
# андерсена
# гримм
# 83
# неточная
# цитата
# максим
# моралиста
# франсуа
# 1613
# 1680
# памятью
# 1971
# 84
# 1855
# антрепризой
# выбились
# составе
# парижский
# маркизы
# 1588
# 1665
# объединял
# претендовавших
# законодателей
# сатирически
# изобразил
# мольер
# комедиях
# жеманницы
# насмешливого
# 87
# воинскому
# уставу
# утвержденному
# двадцатипятилетняя
# солдатчина
# заменялась
# краткосрочной
# службой
# армии
# воинская
# привлекает
# участию
# отправлении
# мужское
# население
# допущения
# замены
# устава
# обсуждался
# течение
# переходящие
# transcendere
# переступать
# опытного
# 89
# оссиановских
# оссиановские
# романтических
# песен
# оссиана
# опубликованных
# 1765
# дж
# макферсоном
# 1736
# 1796
# оссиан
# воспевал
# преданных
# самоотверженных
# низкорослый
# годный
# поделки
# ободья
# оглобли
# полозья
# тульском
# говоре
# обида
# обижда
# поношение
# даль
# толковый
# словарь
# 583
# убыточная
# назначенная
# 91
# оды
# 1743
# 1816
# измерить
# океан
# глубокий
# 92
# казначейские
# билеты
# стоимостью
# выпущенные
# увеличения
# оборотных
# ускоренного
# выпускались
# разрядами
# приносили
# процента
# прибыль
# уплачивалась
# сроки
# сериями
# проценты
# наступления
# сроков
# платежа
# 93
# редкостью
# практические
# электрического
# освещения
# исключительных
# содержатели
# увеселительных
# заведений
# обзавелись
# новинкой
# освещено
# электрическим
# 94
# поместила
# четырехверстных
# офицерских
# императорского
# высочества
# инспектора
# кавалерии
# объявляется
# войскам
# красносельская
# призы
# императорской
# произведена
# предназначены
# отправлению
# прибыть
# село
# помещения
# ипподрома
# палатки
# северный
# остров
# народных
# преданиях
# фауста
# гете
# анри
# мельяка
# людовика
# 1834
# актрисой
# стелла
# колас
# пьесы
# жильберты
# капризничаете
# поете
# исчезаете
# мельяк
# 98
# китае
# пясецкий
# качестве
# врача
# экспедиции
# опубликована
# переиздавалась
# европейских
# курортному
# списку
# 104
# спутница
# 105
# вдовий
# благотворительные
# неимущих
# престарелых
# вдов
# прослуживших
# погибших
# впадать
# 108
# записалась
# отводившее
# благочестию
# обрядности
# времен
# распространенный
# уживался
# проявлениями
# фанатичности
# тиранства
# синонимом
# ханжества
# светлость
# склонная
# порыва
# 112
# метемпсихозы
# древних
# восточных
# религий
# буддизма
# переселении
# душ
# последовательно
# воплощающихся
# телах
# важами
# важи
# чемоданы
# телячьей
# vache
# 115
# менелая
# елена
# оперетта
# менелай
# оперетте
# комический
# обманутого
# евгюбические
# надписи
# таблицы
# умбрийском
# диалекте
# найденные
# 1444
# gubbio
# euggubium
# 119
# многочисленные
# спекуляция
# подоспела
# гигантским
# новороссии
# войска
# донского
# степей
# практического
# получать
# субсидии
# обогащения
# 120
# уфимской
# оренбургской
# губерниях
# башкиры
# владели
# целях
# поощряло
# переселенцами
# центральных
# арендованные
# участки
# условно
# открывался
# злоупотреблений
# особые
# льготных
# хищническое
# использование
# казенных
# спекуляциях
# чиновники
# оренбургского
# огласку
# валуев
# имуществ
# каренине
# валуева
# 570
# поболтаем
# 123
# faux
# bond
# 124
# пословицы
# jeter
# bonnet
# pardessus
# moulins
# стирку
# 129
# груз
# 130
# топчачок
# молотилка
# приводимая
# топчущимися
# герман
# делич
# экономист
# политик
# выдвинул
# кооперативов
# ссудно
# сберегательных
# касс
# образцу
# ссудного
# классовые
# 132
# лассаль
# 1825
# основатель
# германского
# союза
# кооперативам
# противопоставил
# производственную
# ассоциацию
# получающую
# поддержку
# контакт
# бисмарком
# вело
# союзу
# монархией
# попечения
# улучшении
# фабрикантом
# дольфусом
# мильгаузене
# эльзас
# строило
# стоимость
# приобретая
# собственность
# дольфуса
# коммерческим
# предприятием
# благотворительными
# мильгаузеновское
# 134
# герберта
# 1903
# правильному
# напечатан
# спенсер
# эволюции
# просвещение
# создает
# 135
# напечатана
# фактора
# производстве
# капиталисты
# применены
# странам
# факторы
# социолог
# 136
# склонность
# начетчиков
# ссылаться
# неведомые
# 137
# вениамин
# 1706
# 1790
# американский
# государственный
# рекомендовал
# издания
# черткову
# прошлое
# арендаторы
# гостили
# принцы
# дании
# торжествами
# бракосочетания
# альфреда
# эдинбургского
# янв
# февр
# 141
# гемза
# гемзе
# немецк
# gemse
# европейская
# лань
# серна
# швейцарских
# альп
# ковать
# толочь
# установление
# учреждена
# судебной
# реформой
# модной
# профессией
# иного
# pence
# попались
# бронза
# ковры
# перешагните
# 145
# улаживается
# добровольно
# устраивает
# циничности
# неудобные
# принявший
# предается
# покаянию
# характеристическая
# законодательства
# лишается
# 146
# начальная
# гафиза
# богослов
# дуйся
# аттическая
# язвительность
# едкое
# остроумное
# изречения
# cum
# grano
# salis
# 149
# деверем
# 150
# проекту
# учреждены
# училища
# классические
# преподавание
# естествоиспытатель
# демократ
# сплелись
# нераздельное
# школьной
# реформе
# нигилизма
# 151
# 152
# нравственному
# хору
# слышится
# согласии
# характерных
# хоровом
# аксаков
# 1861
# фрум
# указатель
# пассажирских
# пароходных
# сообщений
# froom
# railway
# guide
# for
# russie
# continent
# of
# europe
# 156
# ремесла
# чацкого
# грибоедова
# великолепие
# faste
# 159
# якобо
# робусти
# прозванию
# 1518
# 1594
# венецианской
# заново
# наследницей
# католическом
# православном
# рациональном
# духовном
# западном
# киреевский
# 1856
# 1852
# 161
# христу
# ивановым
# крамской
# пустыне
# антокольский
# иторическая
# взглянувшая
# традиционные
# церковно
# сюжеты
# давшая
# небесного
# стасов
# 1894
# 516
# относил
# давида
# иисуса
# эрнеста
# ренана
# 1823
# происхождения
# ренановскому
# 414
# перелома
# творчество
# эволюция
# 164
# рафаелевых
# рафаэль
# санцио
# 1483
# 1520
# возрождения
# принадлежат
# сикстинской
# капеллы
# ватикана
# сикстинская
# мадонна
# несение
# креста
# преображение
# историческая
# стремилась
# традиции
# рафаэля
# рафаэлевскую
# идеями
# боткин
# иванов
# 345
# 165
# прерафаелита
# братство
# preraphaelite
# brotherhood
# 1848
# габриэль
# вильям
# гольман
# гент
# академических
# традиций
# изучению
# итальянских
# дорафаэлевской
# джотто
# боттичелли
# теоретиком
# рескин
# прерафаэлитизм
# символистами
# художники
# создававшие
# реалистического
# гладью
# неаполя
# ливий
# зимняя
# стоянка
# ганнибала
# пунической
# изнежила
# телесно
# капуе
# армия
# утратила
# разбита
# неприятелем
# неологизм
# delices
# capoue
# капуи
# лени
# вредная
# нарушила
# запрет
# 169
# осип
# комиссаров
# крестьянин
# шапочный
# костромы
# апреле
# каракозову
# стрелявшему
# комиссарова
# зачислили
# непременным
# посетителем
# салонов
# клубов
# собраний
# спился
# 170
# куджицкого
# иован
# 1899
# сербский
# боровшийся
# турецкого
# австрийского
# 176
# карлотта
# 1840
# 1889
# гастролировавшая
# выступления
# музыкального
# фейерверка
# сенсацию
# забывают
# перевелись
# расцвете
# 185
# родственники
# 186
# святоши
# 187
# суматоху
# 188
# гвоздева
# топографические
# деталей
# гвоздевское
# речке
# солове
# карамышева
# полотном
# произведениях
# яснополянский
# цыпленок
# проникает
# возница
# ахилла
# илиады
# разговорной
# употребляется
# шутливое
# прозвание
# четверкой
# восхитительны
# здравствует
# восхитительна
# 203
# ухаживает
# волочится
# флирт
# ревнивым
# 212
# 213
# вегикул
# vehiculum
# 214
# конек
# мелочь
# являетесь
# пощажу
# порядочен
# простодушен
# восхитительно
# теннис
# заставлять
# томиться
# перешагнуть
# тонкости
# сводится
# проволоки
# сложно
# обожаю
# перестаньте
# причудами
# гласный
# полномочий
# 242
# развратнейшая
# безнравственно
# прозаична
# 247
# книжный
# магазин
# помещался
# кузнецком
# государственном
# перевороте
# 251
# запанибрата
# собрании
# кандидатом
# 253
# ободрить
# телеграфом
# 257
# тэна
# ипполит
# тэн
# историк
# критик
# разуме
# впечатлениями
# восклицание
# турцией
# султана
# прекращалась
# восстала
# повстанцы
# объединились
# отряды
# четы
# партизанскую
# событиях
# черногории
# свинтича
# манию
# праздновать
# юбилеи
# 381
# 416
# поветрием
# 260
# январском
# главы
# публиковалась
# начатую
# университетскими
# любимов
# университетской
# автономии
# обвиняли
# предает
# ставилось
# громившего
# сатирическое
# любимову
# полуофициальное
# выходившее
# 1842
# отражало
# аристократического
# 262
# синих
# перечитывает
# современными
# облике
# тютчева
# славянофильских
# питал
# свояки
# вечная
# женственность
# 265
# рихард
# 1813
# композитор
# теоретик
# реформатор
# связывал
# программной
# теорией
# синтетического
# синтетической
# сочетаются
# архитектура
# идеале
# равновеликими
# постановки
# опер
# нибелунгов
# императорском
# байрейте
# отличались
# торжественностью
# вагнеризм
# вагнеру
# вагнеровскому
# критически
# высказывания
# вагнере
# трактате
# 266
# 1902
# выставленный
# художеств
# пушкин
# изображен
# сидящим
# скале
# герои
# произведений
# пластическим
# пушкинских
# незримый
# знакомцы
# давние
# 1841
# приезжавшая
# гастролями
# особенностями
# считались
# неугомонная
# пылкая
# подвижность
# созданные
# миньон
# церлины
# жуан
# моцарта
# бизе
# 268
# аналогии
# комедией
# фигаро
# безумным
# карнавал
# танцевальный
# 270
# поклонов
# 271
# сенсационный
# подкупленные
# струсбергом
# ссуду
# залог
# процентных
# котировались
# бирже
# обнаружился
# следствию
# привлекли
# 1200
# струсберг
# выслан
# скандальном
# инфернальная
# адская
# inferno
# игорная
# острослов
# mot
# наседкой
# 276
# рекламировалось
# роскошное
# гальбергеровское
# иллюстрациями
# гюстава
# рисунками
# божественной
# кихоту
# сервантеса
# потерянному
# возвращенному
# раю
# мильтона
# эстетическую
# трактовку
# 277
# манифесты
# натурализма
# парижские
# эмиля
# экспериментальный
# чертой
# точное
# воспроизведение
# безусловное
# романического
# вымысла
# 402
# натурализму
# одухотворяющая
# дается
# набил
# валяй
# 422
# программы
# натуралистов
# продолжена
# 278
# 279
# комбинации
# широкое
# удавалось
# 285
# пародийное
# составлено
# наименований
# существовавших
# поземельного
# западных
# 286
# слывешь
# свободомыслящим
# 291
# влиятельная
# сомнамбула
# дугласа
# юма
# дуглас
# юм
# безбородко
# перевоплощение
# скитающегося
# аристократа
# ясновидящего
# 293
# покровом
# душеспасительных
# брошюр
# мистического
# проповедями
# лорда
# гренвиля
# 1913
# посредством
# заключалась
# гибелью
# искупил
# просьбе
# марта
# проповедник
# природу
# человеческую
# последним
# купальном
# меблированных
# парикмахер
# причесываюсь
# тютькина
# притупился
# тетя
# 312
# покушения
# каракозова
# прибыла
# американская
# дипломатическая
# миссия
# царю
# поднесен
# вашингтонского
# конгресса
# нации
# шумными
# обедами
# раутами
# столице
# откликов
# печати
# герцена
# америка
# герцен
# 1959
# 313
# самарский
# засуха
# ведомостях
# приславшего
# самарцев
# редакционной
# ведомостей
# текущего
# поступило
# нуждающихся
# неурожая
# 829
# 314
# освобождении
# актуальных
# восстание
# боснии
# сербия
# назревал
# конфликт
# болгарии
# похода
# константинополь
# сербское
# восьмую
# 315
# возникли
# комитеты
# кадровые
# театру
# вступила
# отставные
# добровольческом
# глеб
# очерках
# прострация
# 320
# 1854
# 1901
# борец
# ливадию
# александром
# поддержке
# долгой
# признана
# 321
# предшествовавшие
# писания
# занимают
# привлекали
# тружеников
# оторванности
# постановку
# этики
# идеалистических
# воззрений
# наилучшие
# накладывала
# отпечаток
# рассуждает
# 1969
# мыслителя
# артура
# 1788
# безнадежными
# пессимистическими
# негреющая
# одежда
# подстановка
# заменяется
# подсказана
# эпиграфом
# равное
# сердцевины
# афанасий
# 323
# хомяков
# 1804
# крупнейший
# богословских
# сочинениях
# катехизисного
# отдельного
# мышления
# доступна
# мышлений
# томе
# изданных
# 1867
# праге
# 324
# alphons
# альфонс
# карр
# журналист
# издавал
# сатирические
# сборники
# остроумные
# памфлеты
# opinion
# national
# остроумным
# писателем
# цитировал
# повестей
# одумайтесь
# писателями
# 464
# 465
# 569
# юрий
# корнилов
# погиб
# 1975
# 462
# бирюков
# 1923
# 572
# мошин
# поляна
# васильевка
# 1904

# %%
import re

def hapax_function(file_name):
    with open(file_name, encoding='utf-8') as file:
        list_of_words = re.findall('\w+', file.read().lower())
    
    freqs = {key: 0 for key in list_of_words}
    
    for word in list_of_words:
        freqs[word] += 1

    for word in freqs:
        if freqs[word] == 1:
            print(word)

hapax_function('krabriye-begletsy-Kuprin.txt')
# Out:
# текст
# сверен
# изданием
# собрание
# сочинений
# 9
# томах
# 7
# м
# худ
# литература
# 1973
# 90
# 99
# соседи
# кроватям
# казенного
# сиротского
# каждому
# десятью
# одиннадцатью
# годами
# вялый
# слабенький
# простое
# веснушчатое
# тверской
# крестьянки
# кличут
# светлые
# ресницы
# мутно
# голубых
# открытый
# мокрый
# капля
# плох
# драке
# чувствителен
# плачет
# боится
# темноты
# альбинос
# белыми
# длинной
# подбородка
# голове
# красными
# белками
# шероховатой
# кожей
# приходит
# воскресеньям
# большеголовый
# красноглазый
# чисто
# выбритый
# появляется
# роскошной
# приемной
# зале
# помещается
# бывшем
# дворце
# графа
# опрятненьком
# отставном
# военном
# мундире
# украшенном
# рядами
# серебряных
# пуговиц
# неизменный
# платок
# завязаны
# яблоки
# вкусные
# темные
# стороне
# выведена
# ножиком
# косая
# решетка
# скромен
# послушен
# учится
# несмотря
# подлиза
# тихоня
# зубрила
# отмечено
# неуловимыми
# чертами
# вкуса
# удачи
# старческой
# добротности
# опрятно
# носит
# казенную
# парусиновые
# панталоны
# парусиновую
# рубашку
# обшитую
# ворота
# форменной
# кумачовой
# лентой
# вещички
# перочинный
# ножик
# перышки
# пенал
# резина
# карандаши
# блестят
# купленные
# придумывает
# новых
# игр
# любую
# игру
# способен
# внести
# серьезной
# увлекательности
# милого
# порядка
# праздникам
# воспитанников
# открыта
# библиотека
# непременно
# выберет
# общей
# зависти
# занимательную
# книгу
# приключениями
# яркими
# картинками
# попросят
# гомера
# недоумением
# тоской
# длинными
# фразами
# заключенными
# саженные
# строки
# попадаются
# двойные
# букв
# каждом
# мальчишеского
# самолюбия
# хотят
# сознаться
# ошибке
# прочитанное
# труда
# запоминает
# пересказывает
# товарищам
# толково
# суховато
# фантазер
# воображение
# неистощимо
# чудовищно
# пышно
# классного
# обучения
# малолетней
# часы
# оставшиеся
# ужина
# прилежные
# плели
# способу
# фребеля
# коврики
# разноцветных
# бумажек
# расшивали
# шерстями
# выколотых
# картоне
# попугаев
# клеили
# домики
# измазав
# сплошь
# грифелем
# разводили
# намусленного
# облака
# макароны
# рассказывал
# мечтательным
# слушателям
# пестрые
# чудесные
# прежней
# домашней
# жизни
# охватывал
# вдохновенный
# восторг
# значило
# происходило
# увезен
# трехлетним
# ребенком
# забытый
# богом
# людьми
# ежегодно
# выгорая
# плоской
# безводной
# пыльной
# равнины
# старшие
# братья
# главные
# действующие
# историй
# поумирали
# дожив
# двухлетнего
# возраста
# задолго
# рождения
# скромным
# письмоводителем
# мирового
# посредника
# имений
# деревни
# щербаковки
# села
# зубова
# проигранных
# прокученных
# буйными
# предками
# лишь
# спорных
# кем
# запаханных
# десятины
# умом
# скучное
# настоящее
# собственное
# яркое
# заманчивое
# сказочно
# прекрасное
# ночь
# булку
# яблоко
# богатым
# людным
# городом
# москвы
# красивее
# шумели
# дремучие
# расстилались
# непроходимые
# болота
# текли
# быстрые
# деревнях
# жили
# тысячи
# преданных
# крепостных
# пожелавших
# уходить
# могущественным
# человеком
# грозным
# судьею
# великодушным
# барином
# отличался
# сверхчеловеческой
# рукой
# останавливал
# бешеную
# кулака
# пробивал
# насквозь
# иннокентий
# построил
# удивительную
# машину
# бегавшую
# земле
# плававшую
# водою
# летавшую
# борис
# владел
# секретом
# приготовлять
# цвета
# воздуха
# надев
# всякий
# невидимкой
# замечательно
# скакал
# белом
# арабском
# иноходце
# метко
# стрелял
# ружья
# игрушечного
# взаправдышного
# бившего
# целую
# версту
# главным
# занятием
# братьев
# великие
# кровавые
# против
# местных
# населявших
# мрачные
# дебри
# наровчатских
# лесов
# богатырские
# военные
# хитрости
# ночные
# засады
# перестрелки
# ночлеги
# лесных
# трущобах
# костров
# брата
# беззвучно
# целыми
# часами
# подползали
# животах
# становищу
# врагов
# прикидывались
# мертвыми
# выведать
# секреты
# спасаясь
# преследования
# ныряли
# плыли
# сотни
# послушно
# прибегали
# верные
# кони
# условный
# свист
# замаскировать
# отчасти
# достоверности
# рассказа
# носил
# штанами
# привязанные
# ходули
# лице
# прицепные
# бороду
# разговоры
# разбойниками
# вел
# звериным
# ловили
# сажали
# острог
# отправляли
# сибирь
# исчезновением
# пропадала
# канва
# жутких
# сладких
# рассказов
# убегали
# тюрьмы
# острога
# снова
# появлялись
# окрестностях
# знаменитого
# пылая
# жаждой
# мести
# наводя
# мирных
# жителей
# имена
# гаврюшка
# орешка
# фома
# кривой
# степан
# клеветник
# необыкновенной
# ясностью
# волосатые
# рожи
# белые
# зубы
# коренастые
# корявые
# рубахи
# длинные
# кухонные
# ножи
# поясом
# алексеевна
# румяная
# толстушка
# черными
# усиками
# губе
# остальных
# чудовищ
# юбках
# тощих
# желтых
# подвязанными
# ушами
# горлами
# щеками
# злых
# крикливых
# нервных
# классных
# дам
# классах
# одна
# оставила
# отрадное
# впечатление
# упреков
# бывала
# мила
# приветлива
# ласкова
# выходила
# комнатки
# бледная
# головой
# повязанной
# полотенцем
# запахом
# туалетного
# уксуса
# становилась
# нетерпеливой
# придирчивой
# кричала
# стучала
# маленьким
# кулачком
# столу
# плакала
# раздражения
# любила
# поощряла
# нашептывание
# степени
# случалось
# угоду
# ехидно
# втравлял
# какую
# невинную
# недозволенную
# пакость
# стремительно
# бежал
# даме
# захлебываясь
# пузырями
# губах
# доносил
# ту
# полосу
# немилости
# доложил
# ольге
# алексеевне
# изумительных
# героических
# похождениях
# миши
# совершила
# несправедливость
# позвала
# жестоко
# неотразимой
# правдой
# доказала
# вздорность
# россказней
# постепенно
# увлекаясь
# краснея
# охватившего
# гнева
# назвала
# вралишкой
# услужливый
# хохот
# других
# подзадоривал
# склеила
# белой
# высокий
# остроконечный
# колпак
# написала
# нем
# чернилами
# кистью
# жирное
# лгун
# велела
# носить
# позорный
# убор
# целых
# снимая
# занятий
# едой
# молитве
# сжался
# затаился
# увлекательность
# вымысла
# сильнее
# воли
# разделял
# четвертушку
# правильные
# квадратики
# мелко
# рисовал
# знаменитую
# историю
# борьбы
# защитниками
# справедливости
# переходом
# группы
# классы
# обычаи
# нравы
# занимались
# надзором
# преподавания
# наук
# учители
# очках
# фраках
# золотыми
# пуговицами
# убирали
# водили
# баню
# горничные
# усатых
# дядьки
# случае
# надобности
# секли
# ребят
# приказанию
# начальницы
# высокая
# княжеским
# титулом
# серолицая
# сероглазая
# ушах
# вдеты
# золотые
# колокольчики
# языками
# камешков
# издали
# слышался
# шум
# каменных
# легкий
# перезвон
# сережек
# мальчишки
# цепенели
# внутренняя
# стала
# иной
# считали
# линии
# будущих
# гимназистов
# жаловаться
# ябедничать
# преступлением
# уважалась
# сила
# грубость
# старшими
# пренебрежение
# наукам
# единицы
# нули
# баллы
# двоек
# троек
# четверок
# бывало
# рассказчичьи
# таланты
# расцвели
# году
# пылкой
# одних
# странствований
# области
# влекло
# действию
# ранее
# собственный
# удальской
# основал
# бесшабашную
# молодых
# зависимости
# прихоти
# являлись
# казаками
# дикарями
# мстителями
# молотобойцами
# называвшимися
# таинственном
# языке
# сацаро
# даярами
# принимался
# выдерживал
# ударов
# жгучей
# крапивой
# рукам
# огромном
# запущенном
# екатерининском
# саду
# бравые
# молодчики
# предводительствуемые
# атаманом
# палками
# кидались
# чащу
# шиповника
# рубили
# холодея
# вставшими
# дыбом
# головах
# накатил
# стих
# набожности
# стремления
# чудотворству
# власти
# впечатлений
# гроба
# восковым
# старческим
# грустного
# похоронного
# пения
# запаха
# ладана
# открытой
# ваганьковском
# кладбище
# спальне
# голыми
# коленями
# крестился
# вдавливая
# живот
# проникновенным
# самодельные
# бывает
# дикарей
# тихих
# образовалась
# толпа
# последователей
# выпросил
# флакончик
# святой
# творить
# золотушного
# добросердова
# болело
# ухо
# исцелить
# бедняга
# бился
# отбрыкивался
# положили
# бок
# творя
# молитву
# влил
# уши
# ложки
# две
# чайных
# воды
# лечил
# головные
# зубные
# смоченную
# ватку
# удачного
# ответа
# чей
# рассказ
# прочитанная
# книжка
# заставили
# страстно
# желать
# богатства
# попробовал
# выпустить
# разноцветной
# рублю
# десяти
# сделанные
# охотно
# играли
# понарошку
# забавы
# рублей
# перышка
# денежная
# затея
# лопнула
# решился
# золото
# монах
# шварц
# порох
# перетирая
# ступке
# опалил
# неожиданным
# взрывом
# таким
# путем
# наткнуться
# изобретение
# золота
# глубокой
# верой
# таинственным
# подолгу
# жевал
# обильно
# смачивая
# слюной
# комки
# смешивал
# массу
# золой
# печных
# труб
# известкой
# стен
# мелом
# замазкой
# песком
# плевательницы
# гадостью
# попадала
# потихоньку
# постороннего
# взгляда
# клал
# волшебную
# смесь
# пресс
# спальный
# шкафчик
# классную
# учебную
# скамейку
# бьющимся
# вынимал
# сухую
# бесформенную
# лепешку
# шептал
# важным
# значительным
# хватает
# увлечение
# алхимией
# заняло
# недель
# сменила
# полоса
# влюбленности
# неделю
# приезжал
# учитель
# петр
# алексеевич
# круглый
# гибкий
# подвижной
# прекрасном
# фраке
# сияющий
# сопровождении
# лохматого
# унылого
# скрипача
# приемную
# залу
# блестящем
# паркете
# пленительно
# отражались
# люстры
# кенкеты
# мраморные
# бронзовые
# бюсты
# собирали
# половин
# старшего
# класса
# урок
# единственным
# случаем
# встречались
# близко
# церкви
# обедом
# далеко
# разделены
# считались
# низшими
# презренными
# существами
# слабосильными
# фискалами
# плаксами
# неженками
# стоя
# паре
# проделывая
# нею
# унылую
# скрипку
# баск
# глиссе
# особенным
# мужским
# шиком
# дернуть
# косичку
# ущипнуть
# сдавить
# пальцы
# боялся
# наперекор
# общим
# мнениям
# прекрасный
# зимний
# полдень
# хорошенькую
# мухину
# заспанную
# смуглянку
# черноглазую
# скуластую
# милыми
# родинками
# щеках
# подбородке
# заявил
# классом
# становиться
# пару
# скажет
# неуважительное
# побьет
# силачей
# распространил
# таинственный
# многозначительный
# слух
# скрывает
# силу
# поддержания
# товарищах
# мнения
# умывальнике
# намыливал
# тер
# пена
# совершенно
# впитывалась
# кожу
# отвечал
# сумрачным
# топорща
# кулаки
# крепче
# пошла
# поголовная
# мода
# решительно
# перевлюблялись
# поделив
# средневековые
# завоеватели
# рабынь
# сильные
# разбитные
# выбрали
# высоких
# толстых
# румяных
# слабых
# оставили
# слабеньким
# хилым
# писал
# низко
# склонившись
# листом
# почтовой
# подпирал
# усердия
# изнутри
# языком
# сопел
# украсил
# листок
# переводной
# картинкой
# розовый
# конверт
# конверте
# наклеил
# налепную
# картинку
# первом
# потея
# стыда
# страха
# послание
# стихи
# проза
# девочка
# смутилась
# гораздо
# меньше
# засунула
# передник
# покраснела
# урока
# закона
# божьего
# раздался
# тяжкий
# топот
# отчего
# чуткое
# сердце
# похолодело
# затосковало
# полуоткрылась
# дверь
# показалось
# огромное
# серое
# мясистым
# рука
# подзывающим
# указательным
# пальцем
# иди
# ка
# любезный
# бедного
# влюбленного
# повели
# наверх
# дортуар
# разложили
# первой
# сняли
# штанишки
# держал
# дал
# добрых
# розог
# незаметно
# пресеклась
# вскоре
# забылась
# образ
# хорошенькой
# смуглой
# заспанными
# глазками
# надутыми
# губками
# застрял
# памяти
# перечислить
# увлечения
# предпоследнее
# свободное
# летание
# основу
# искусства
# удивляет
# снов
# повторялся
# снилось
# обеими
# руками
# держит
# широкую
# ленту
# крутя
# перепрыгивает
# ногами
# играют
# скакалку
# учащая
# темп
# вращения
# становится
# отделяется
# парит
# потолком
# находился
# таком
# нестерпимо
# хочется
# обратить
# мечту
# явь
# весенних
# индейцу
# племени
# апахов
# черноногих
# прокрался
# запрещенный
# лагерь
# украл
# шнур
# рукоятками
# концах
# мальчишеское
# поле
# уверенный
# чуде
# мифическому
# дедалу
# легендарным
# аполлонию
# тианскому
# симону
# волхву
# нашему
# современнику
# крылатому
# лилиенталю
# взобрался
# полевой
# гимнастики
# перекладину
# крикнул
# глядите
# полечу
# запутался
# веревке
# позорно
# упал
# расквасив
# разбив
# правую
# коленку
# насколько
# проследить
# самым
# последним
# детским
# увлечением
# военную
# окончить
# курс
# разумовских
# воспитков
# вообще
# принимали
# неохотно
# подготовлены
# третьих
# проведши
# лучшие
# годы
# влиянием
# капризных
# первоначала
# исковерканы
# пятидесяти
# экзамен
# десять
# пятнадцать
# телесного
# осмотра
# надежный
# отбор
# количестве
# шести
# счастливцы
# пройдя
# горнило
# науки
# товарищества
# уменьшались
# трех
# худших
# почем
# знать
# талантливых
# ссылали
# плохое
# учение
# ярославскую
# прогимназию
# скверное
# поведение
# вольскую
# современники
# драли
# субботам
# поучение
# особые
# вдвое
# редкие
# крепыши
# назвать
# известных
# скромных
# имен
# конце
# девятнадцатого
# начале
# двадцатого
# столетия
# второстепенных
# именах
# пылких
# грезах
# бывал
# скобелевым
# гурко
# радецким
# окончания
# войны
# 1877
# 1879
# годов
# простирается
# мальчишеская
# дерзость
# наполеоном
# заранее
# иная
# приходилось
# веровать
# прибегнуть
# коленях
# изо
# всей
# силы
# прижимал
# выжать
# хоть
# слез
# делал
# заметить
# страстным
# мечтателем
# виде
# невинной
# взятки
# неосуществимые
# обеты
# напрягая
# ведь
# можешь
# сделай
# выдержал
# построю
# зубове
# щербаковке
# церковку
# хорошую
# часовню
# устрой
# похудел
# побледнел
# питался
# хлебом
# прогулках
# травяной
# дрянью
# просвирками
# свербигусом
# молочаем
# научном
# смысле
# крепко
# подналег
# необходимо
# победить
# самолюбивую
# застенчивость
# наоборот
# сдержать
# грубую
# вольность
# языка
# несправедливая
# нагрешил
# невинный
# веселый
# пистолет
# готовила
# серьезное
# испытание
# сменилась
# кажется
# уехала
# лето
# отпуск
# классная
# сухая
# чрезвычайно
# холодная
# справедливая
# первые
# вселяли
# страх
# третье
# уважение
# воскресный
# привела
# сына
# долговязого
# приготовительного
# гимназиста
# поиграть
# мальчиками
# гимназист
# форсил
# показывал
# шведскую
# гимнастику
# перепрыгнул
# стол
# разбега
# разбег
# шага
# вызвал
# любителей
# подраться
# первым
# согласился
# поддерживая
# славу
# главного
# силача
# выступил
# ленивый
# сурков
# уступил
# очереди
# минут
# боксера
# красны
# застала
# зрелище
# правосудно
# поставила
# угол
# лицемерно
# добродетельными
# лицами
# шоколад
# приготовленный
# первого
# знакомства
# приготовишки
# воспитанниками
# ушла
# смену
# временно
# длинная
# коротконогая
# девица
# огромной
# лошадиной
# мордой
# носила
# короткие
# юбки
# выглядывали
# невероятно
# прюнелевых
# башмаках
# ушками
# вонючей
# пудрой
# бровями
# росла
# бородавка
# похожая
# цветом
# спелую
# малину
# формою
# рог
# носорога
# рок
# фабрикует
# наружности
# характера
# убеждена
# непоколебимости
# нравоучительных
# анекдотов
# воскресных
# прописей
# каждое
# взятое
# книжки
# считала
# священным
# сразу
# естественному
# отвращению
# юном
# чувствовался
# настоящий
# умеют
# ненавидеть
# старые
# мелочные
# скучающие
# девиц
# претили
# движения
# звук
# невольные
# привычные
# гримасы
# живость
# объяснить
# умела
# самом
# нельгине
# ежедневно
# оставляли
# завтрака
# обеда
# лишали
# свиданий
# приходил
# выбрала
# терпением
# проницательностью
# мстительницы
# больное
# чувствительное
# заставляла
# общих
# катались
# гигантских
# шагах
# строили
# великолепные
# пещеры
# песка
# устраивали
# веток
# сады
# огороды
# назло
# добросовестно
# терпеливо
# игры
# неинтересны
# простирался
# огромный
# окаймленный
# густым
# лесом
# вернувшись
# стариком
# убедился
# ста
# квадратных
# саженей
# лес
# сирени
# прерии
# пампасы
# льяносы
# нестись
# зеленой
# скривив
# челюсть
# набок
# закусив
# удила
# склонив
# галопом
# необозримой
# усеянной
# ромашкой
# одуванчиками
# голубыми
# неведомыми
# цветами
# остро
# пахучими
# травами
# сказали
# прощаются
# стояния
# должен
# отбывать
# обещай
# отбыв
# стояние
# побежишь
# траве
# обещал
# искренно
# побежать
# побежал
# мнении
# воспитательниц
# мальчиком
# никак
# сидя
# ногах
# приподнявшись
# локте
# лежал
# моего
# товарищи
# читали
# капитана
# гранта
# пятнадцати
# командовал
# трехмачтовым
# кораблем
# фок
# бизань
# такелаж
# грот
# вещи
# шкоты
# скажем
# одиннадцати
# взять
# хлеба
# посолить
# спрятать
# карман
# хозяева
# аглаида
# семеновна
# пензе
# устроим
# ночлег
# некоторые
# трусы
# подлизы
# стороны
# дипломатический
# подход
# расстегнул
# поднял
# удобно
# слушать
# продолжал
# здесь
# мучают
# притесняют
# каждой
# ерунды
# ругают
# ставят
# война
# кончилась
# удрать
# деловито
# заметил
# лодке
# запастись
# провизией
# деньгами
# замечательный
# прием
# заговорщиков
# переночуем
# фирсыча
# даст
# наровчата
# наше
# имение
# щербаковку
# зубово
# фантазия
# разгорается
# обыкновению
# встречают
# крестьяне
# молоко
# продаю
# десятин
# надеваем
# платье
# пароход
# верная
# шепотом
# веско
# убежишь
# спускает
# профискалит
# ехать
# паровику
# паровик
# чепуха
# ходить
# своими
# любимчиками
# жжик
# парк
# яузу
# кудринской
# площади
# дойдем
# вечеру
# уж
# поверьте
# даю
# мое
# благородное
# нетрудно
# увлечь
# юрьева
# шел
# смелым
# предприимчивым
# которому
# стыдно
# обязательного
# молодечества
# отказаться
# компании
# отметить
# хотел
# обманывать
# душой
# поэта
# путешественника
# сделается
# предполагал
# вышло
# маленькое
# осложнение
# решившее
# побега
# рассказывала
# летело
# стадо
# навстречу
# гусь
# зла
# придирчива
# плохой
# желудок
# получалось
# востребования
# задача
# гусях
# заинтересовала
# просунул
# стриженую
# забыв
# минуту
# своем
# побеге
# хлеб
# кармане
# увидела
# ненавистное
# понюхала
# брезгливо
# сморщилась
# воробьем
# летом
# волосы
# выгорают
# птицей
# обиделся
# ответил
# дура
# мышами
# грязное
# готово
# хватается
# кричит
# уберите
# отсюда
# уведите
# гнусного
# иначе
# ручаюсь
# берите
# пример
# таких
# глупых
# гадких
# будешь
# дни
# моих
# дежурств
# самой
# глядел
# солнце
# жмурился
# орлы
# глядят
# солнцу
# орел
# гляжу
# слезы
# текут
# градом
# насыпали
# горсточку
# песку
# обложили
# сырой
# землей
# снизу
# отковырнули
# дверцу
# осторожно
# пальцами
# выгребли
# песок
# получился
# великолепный
# рыцарский
# замок
# разбойничья
# пещера
# дураки
# думает
# вставить
# прутик
# листиком
# флаг
# кругом
# воткнуть
# цветы
# попадутся
# получится
# дивный
# замковый
# краем
# сознания
# подойдут
# выждав
# подошли
# заговорщики
# небрежно
# дано
# бежим
# помялись
# обо
# услышите
# буду
# миллионером
# найду
# генералов
# фискалить
# вами
# знаком
# мной
# знакомы
# зачарованы
# игрой
# дали
# клятву
# другу
# замялся
# овладел
# положением
# подумаешь
# тоже
# приедем
# вышлю
# целый
# воз
# битых
# индюков
# кур
# соболью
# шубу
# жеребцов
# сундук
# папу
# возьмем
# обрабатывать
# кордильеры
# ходила
# взад
# окруженная
# толпою
# прилежных
# учеников
# оставляю
# совести
# невежественная
# злая
# говорила
# тремя
# заговорщиками
# идиотским
# скосив
# рвал
# нюхал
# травки
# третий
# предавался
# танцевальному
# искусству
# проплыла
# трое
# бросились
# неизвестная
# разрослись
# волчья
# ягода
# жимолость
# бузина
# глухая
# крапива
# лопухи
# дикий
# тмин
# божьи
# дудки
# просвирняк
# грибами
# пробираться
# катятся
# какому
# бесконечному
# лесному
# обрыву
# чаща
# поредела
# показалась
# дорожка
# побежали
# кружили
# послышались
# детские
# распознал
# приближаются
# той
# части
# парка
# которая
# отведена
# бежать
# голосов
# незнакомом
# месте
# текла
# черная
# вонючая
# быстрая
# яуза
# приток
# дрогнула
# приличная
# душа
# лучше
# оставим
# кроме
# забыл
# переписать
# чистописание
# решительный
# характер
# забытых
# доски
# остатки
# портомойни
# временного
# моста
# гнили
# величием
# смешно
# детях
# взрослых
# твое
# переплывем
# реку
# снимай
# обшлага
# мигом
# сорвал
# кумач
# воротника
# сделал
# поколебался
# одну
# благоразумие
# взяло
# прощайте
# профискалишь
# богу
# ушел
# сели
# неустойчивый
# плот
# обмакивая
# заставляя
# двигаться
# движением
# тел
# добрались
# противоположного
# неведомый
# руководил
# движениями
# скувырнулись
# потонули
# камни
# обрывисты
# глубокая
# плавать
# умели
# выбрались
# ползком
# противоположный
# берег
# ясно
# почувствовали
# расчеты
# прошлым
# покончены
# услышали
# подобный
# грому
# больших
# холеных
# сенбернара
# летели
# сказать
# видали
# картинке
# разинутые
# пасти
# языки
# частое
# дыхание
# действительность
# корявая
# дуплистая
# ива
# висела
# речкой
# быстротой
# вскарабкались
# ветви
# сидели
# поджав
# мокрые
# дрожа
# пришел
# грязный
# черным
# заставил
# замолчать
# живете
# идете
# вдохновенно
# лгать
# вспомнилась
# красная
# шапочка
# идем
# бабушке
# менее
# покровительством
# контору
# управляющему
# железоделательного
# завода
# дангаузер
# толстый
# опившийся
# пивом
# спокойный
# спрашивал
# лениво
# нитки
# ловко
# сорванных
# обшлагов
# навели
# правильную
# мысль
# этих
# называется
# елизаветинское
# пансионом
# отдались
# победителя
# промах
# помилуйте
# женский
# просим
# указать
# сказав
# черному
# человеку
# гляди
# украли
# проводил
# двору
# свете
# угасавшего
# летнего
# цветились
# радугой
# валялись
# обломки
# железа
# хлором
# находятся
# выйдя
# андрониевского
# монастыря
# странным
# покажется
# прохожих
# частью
# получали
# ответ
# насмешливый
# явно
# лживый
# поверни
# трубу
# трубой
# сапожник
# сапожником
# пирожник
# парикмахера
# напудрено
# идите
# никуда
# сворачивая
# маленькие
# ходят
# одни
# фамилии
# чутье
# подсказало
# верить
# глумливым
# указаниям
# отвечать
# вопросы
# начался
# куксился
# край
# света
# пансионе
# кошелек
# семью
# копейками
# образок
# благословение
# думала
# умирать
# понимал
# уступить
# поколебаться
# сдаться
# значит
# потерять
# сделаться
# смешным
# своему
# велик
# минуты
# давай
# прикинемся
# бродячие
# итальянцы
# молякаля
# селя
# малям
# лям
# ля
# налям
# калям
# прохожие
# шарахались
# выпустили
# идиотов
# инстинкт
# бродячего
# круговращения
# заводил
# фонтанам
# льют
# бассейны
# лакали
# подлая
# бессердечная
# москва
# утолял
# жажду
# болван
# верзила
# разносчик
# снял
# лоток
# поставил
# бережно
# мостовую
# расчетливо
# ударил
# захлебнулся
# раздышался
# жуткий
# центре
# шли
# людной
# узкой
# богатой
# спросили
# вежливый
# честный
# вернуться
# повернуть
# следующую
# попадете
# устали
# предпочитали
# упорно
# бессмысленно
# прямому
# направлению
# лефортова
# карте
# восьми
# всеми
# нелепыми
# кривулями
# сделали
# дошли
# нашли
# напротив
# вдовьего
# дома
# дом
# года
# жена
# удивлены
# позднему
# посещению
# прекрасной
# женщины
# побежденные
# красноречием
# оказали
# гостеприимство
# сделать
# комната
# окно
# коридор
# пустовала
# усталый
# изодранный
# врал
# последних
# сил
# петровском
# парке
# ехали
# потеряли
# товарищ
# боимся
# поздно
# предложили
# булкой
# склонен
# попить
# поесть
# осторожен
# ели
# пообедали
# этим
# слабовольным
# получеловеком
# каждую
# готов
# расплакаться
# постелили
# одеяло
# подушку
# дрожал
# городской
# писарем
# времена
# бабушки
# остроумия
# гласные
# безгласные
# безгласный
# жены
# семь
# собачонок
# маленьких
# черных
# короткошерстых
# рыжими
# пятнами
# газету
# кормил
# вареной
# про
# бормотал
# отлично
# печенку
# доедают
# лежи
# шевелись
# достану
# пищу
# ощупью
# набрел
# тарелку
# сытые
# поворчали
# обнюхав
# успокоились
# печенке
# весу
# полуфунта
# хватило
# блаженный
# усталых
# тружеников
# сновидений
# просыпа
# наступило
# утро
# проснулись
# освеженные
# дух
# предприимчивости
# юрьеве
# угас
# вчерашний
# огонь
# иссякла
# энергия
# настоящая
# тверская
# кривя
# дергая
# ответить
# откровенно
# протрезвившись
# дальнейшей
# судьбы
# сообразил
# сегодня
# шелестел
# газетой
# газета
# подсунута
# почтальоном
# дверную
# щелку
# газетах
# печатают
# беглых
# мальчиках
# момента
# развернет
# шелестящий
# лист
# земля
# пухом
# догадывался
# нескромным
# вопросом
# смутил
# беглецов
# предложил
# ответили
# торопимся
# этакие
# деловые
# миром
# сей
# поры
# предположения
# сбылись
# осталось
# сесть
# поехать
# изумительный
# крепостным
# верноподданным
# творит
# нужны
# уверенность
# голос
# другое
# лишнее
# очутившись
# заныл
# хочу
# домо
# ой
# пансио
# подло
# зная
# глубине
# кончится
# сдачей
# товарищески
# бою
# юсь
# ладно
# сходим
# ет
# высокого
# триста
# каланча
# покрова
# пруды
# перелезть
# барьер
# иметь
# мужество
# прыгнуть
# болото
# пояса
# проходишь
# контроль
# прыгал
# вымазался
# весь
# черт
# оставаться
# одному
# страшнее
# сиганул
# вслед
# независимым
# грязные
# следами
# оторванных
# лацканов
# невыспавшиеся
# какаду
# страуса
# причем
# стравил
# камень
# найденный
# дорожке
# ключ
# карманных
# часов
# слонов
# тигров
# многих
# птиц
# вонючих
# хорьков
# лис
# гиппопотама
# высовывал
# густой
# разинутую
# похожую
# чемодан
# розовой
# подкладкой
# подразнили
# потрогали
# колючего
# дикобраза
# остановил
# загадкой
# область
# исследованная
# пришлось
# плакать
# подзуживал
# скажи
# затеял
# путь
# долог
# помогли
# бессознательная
# животная
# местности
# дневной
# свет
# часам
# трем
# стояли
# дворники
# прачки
# полотеры
# кухарки
# странно
# обратил
# внимания
# чьи
# правосудные
# отдадут
# схватили
# отвели
# лазарет
# рассадили
# комнаты
# строгим
# запрещением
# видаться
# другом
# сдержал
# обещание
# тяжело
# одиночество
# книг
# разговоров
# вдобавок
# дураком
# одиннадцатилетний
# додумался
# разговора
# стуком
# старик
# будущий
# трус
# отозвался
# стену
# вспомнил
# решил
# арифметические
# задачи
# уме
# подзубрил
# ять
# полудня
# раздались
# каменные
# выдерут
# возьму
# умру
# внезапно
# будут
# жалеть
# те
# г
# уступала
# почетное
# княжне
# л
# лазаретную
# каморку
# новая
# владычица
# веселых
# светских
# барынь
# утлые
# посмотрите
# сокровище
# отдать
# арестантские
# роты
# поглядите
# какое
# придется
# бороться
# милая
# присылают
# знает
# милым
# простым
# добрым
# возразила
# вежливо
# широкий
# зоркие
# упрямая
# возможно
# пропадет
# смотрите
# розовые
# очки
# хотелось
# начинать
# жестокого
# наказания
# итак
# считаете
# возможным
# допустить
# экзамену
# согласна
# наперед
# вашим
# мнением
# опыт
# позволите
# благодарю
# любезны
# ушли
# порядке
# говорили
# французски
# ровно
# понял
# переводил
# разговор
# прежняя
# выпороть
# мальчишку
# другая
# зачем
# худой
# рассказах
# затихли
# женские
# услыхал
# легкие
# эта
# большая
# могла
# легко
# брошенные
# ею
# вдоль
# pardon
# princesse
# извините
# фр
# скучную
# больничную
# комнату
# взяла
# шершавую
# ладонями
# приподняла
# кверху
# внимательно
# поглядела
# читая
# будущее
# колючую
# шерсть
# бойся
# пришлю
# куриного
# бульона
# красного
# вина
# видно
# бледный
# говори
# никому
# выдержишь
# прекрасно
# уверена
# готова
# остановилась
# задумал
# побег
# уговорил
# товарища
# прибавил
# презрением
# такая
# милое
# полное
# княжны
# осветилось
# прелестной
# улыбкой
# дерзкий
# ласково
# загорелой
# исцарапанной
# щеке
# непоседа
# живи
# хочешь
# делай
# бесчестного
# прощай
# наклонилась
# мгновение
# закрытыми
# уловил
# чистый
# сладостный
# запах
# духов
# почувствовал
# лбу
# прикосновение
# нежных
# губ
# повеяло
# слабым
# ветром
# удаляющегося
# платья
# ласка
# чужого
# человека
# комнате
# доносились
# затихающие
# звуки
# легких
# поспешных
# прижал
# обе
# середине
# прошептал
# восторженно
# слезами
# глазах
# 1917

# %%
from textblob import TextBlob

def sentiment_analysis(tokens):
    text = ' '.join(tokens)
    blob = TextBlob(text)
    return blob.sentiment.polarity, blob.sentiment.subjectivity

kuprin_sentiment = sentiment_analysis(kuprin_tokens)
tolstoy_sentiment = sentiment_analysis(tolstoy_tokens)

print(f"Sentiment Kuprin: {kuprin_sentiment}")
print(f"Sentiment Tolstoy: {tolstoy_sentiment}")
# Out:
# Sentiment Kuprin: (0.0, 0.0)
# Sentiment Tolstoy: (0.36258503401360537, 0.6304421768707483)

# %% [markdown]
# Результаты анализа настроений для произведений "Храбрые беглецы" Александра Куприна и "Анна Каренина" Льва Толстого показывают интересные различия. Для "Храбрых беглецов" анализ настроений показал (0.0, 0.0), что указывает на нейтральный тон текста, в то время как "Анна Каренина" имеет положительную полярность (0.36258503401360537) и высокую субъективность (0.6304421768707483), что может отражать более эмоциональную и личностную наполненность текста.
#
# ### Интерпретация результатов
#
# - **Нейтральная полярность "Храбрых беглецов"** может указывать на более объективное или уравновешенное изложение событий в произведении, где автор старается не навязывать читателю свои собственные суждения.
# - **Положительная полярность и высокая субъективность "Анны Карениной"** отражают глубокую эмоциональную проработку персонажей и ситуаций, что характерно для романов Толстого. Это может свидетельствовать о том, что текст богат на описания внутренних переживаний персонажей, их размышлений и чувств.
#
# ### Влияние на анализ влияния эпохи
#
# Эти различия в настроениях могут также отражать изменения в литературных традициях и общественных настроениях эпох, к которым принадлежат произведения. В то время как "Храбрые беглецы" Куприна, написанные в начале XX века, могут отражать период социальных изменений и неопределенности, "Анна Каренина" Толстого, созданная во второй половине XIX века, погружает читателя в мир личных драм и моральных дилемм, характерных для русского общества того времени.

# %%
from collections import Counter

def plot_most_common_words(tokens, num_words=20):
    counter = Counter(tokens)
    most_common = counter.most_common(num_words)

    words = [word for word, _ in most_common]
    counts = [count for _, count in most_common]

    plt.figure(figsize=(10, 5))
    plt.barh(range(len(words)), counts, color='blue')
    plt.yticks(range(len(words)), words)
    plt.gca().invert_yaxis()  # Инвертируем ось Y, чтобы наиболее частые слова были сверху
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.title('Top Words Frequency')
    plt.show()

plot_most_common_words(kuprin_tokens)
plot_most_common_words(tolstoy_tokens)

# %%
from gensim.models import LdaModel

def lda_analysis(corpus, dictionary, num_topics=40):
    lda = LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)
    topics = lda.print_topics(num_words=5)
    for topic in topics:
        print(topic)

lda_analysis(corpus, dictionary)
# Out:
# (1, '0.001*"левин" + 0.001*"ан" + 0.000*"вронск" + 0.000*"кит" + 0.000*"рук"')
# (29, '0.001*"левин" + 0.001*"кит" + 0.001*"ан" + 0.001*"вронск" + 0.001*"рук"')
# (26, '0.002*"левин" + 0.001*"вронск" + 0.001*"рук" + 0.001*"ан" + 0.001*"аркадьич"')
# (21, '0.001*"левин" + 0.000*"вронск" + 0.000*"кит" + 0.000*"ан" + 0.000*"рук"')
# (36, '0.014*"левин" + 0.008*"ан" + 0.007*"вронск" + 0.006*"рук" + 0.006*"кит"')
# (4, '0.001*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.001*"кит" + 0.000*"рук"')
# (11, '0.001*"левин" + 0.001*"рук" + 0.000*"ан" + 0.000*"вронск" + 0.000*"степа"')
# (19, '0.001*"вронск" + 0.001*"левин" + 0.000*"ан" + 0.000*"александрович" + 0.000*"кит"')
# (25, '0.001*"левин" + 0.000*"ан" + 0.000*"вронск" + 0.000*"рук" + 0.000*"александрович"')
# (0, '0.001*"левин" + 0.000*"ан" + 0.000*"рук" + 0.000*"александрович" + 0.000*"вронск"')
# (34, '0.001*"левин" + 0.000*"вронск" + 0.000*"ан" + 0.000*"александрович" + 0.000*"рук"')
# (2, '0.001*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.000*"кит" + 0.000*"рук"')
# (27, '0.001*"левин" + 0.000*"ан" + 0.000*"вронск" + 0.000*"степа" + 0.000*"говор"')
# (32, '0.001*"левин" + 0.000*"ан" + 0.000*"вронск" + 0.000*"рук" + 0.000*"кит"')
# (16, '0.000*"левин" + 0.000*"ан" + 0.000*"вронск" + 0.000*"кит" + 0.000*"степа"')
# (9, '0.001*"левин" + 0.001*"вронск" + 0.001*"ан" + 0.001*"кит" + 0.000*"рук"')
# (5, '0.001*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.000*"рук" + 0.000*"кит"')
# (13, '0.001*"левин" + 0.001*"вронск" + 0.001*"ан" + 0.001*"рук" + 0.000*"дума"')
# (3, '0.001*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.000*"аркадьич" + 0.000*"рук"')
# (7, '0.001*"левин" + 0.001*"вронск" + 0.001*"ан" + 0.000*"рук" + 0.000*"алекс"')

# %% [markdown]
# Результаты тематического моделирования,показывают, что слова "эт" и "сказа" доминируют в большинстве тем. Это может указывать на то, что эти слова являются ключевыми в текстах, но также может быть признаком того, что модель LDA воспринимает их как шумовые слова или слова, которые встречаются чересчур часто и поэтому распределены по всем темам. Возможно, что многократное включение этих слов в темы связано с их высокой частотой и широким использованием в тексте, что делает их менее значимыми для выделения конкретных тем.
#
# Однако, включение слова "левин", которое является фамилией одного из главных персонажей "Анны Карениной", может указывать на то, что часть текста связана с этим персонажем и его действиями или внутренним миром.

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in c:\users\elena\anaconda3\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\elena\anaconda3\lib\site-packages (from pandas) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elena\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elena\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elena\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\elena\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in c:\users\elena\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (1.24.3)
# Requirement already satisfied: scipy in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (1.11.1)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (2.2.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (1.2.0)
# Requirement already satisfied: jinja2 in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (3.1.2)
# Requirement already satisfied: numexpr in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (2.8.4)
# Requirement already satisfied: funcy in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (1.3.0)
# Requirement already satisfied: gensim in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (4.3.0)
# Requirement already satisfied: setuptools in c:\users\elena\anaconda3\lib\site-packages (from pyLDAvis) (68.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\elena\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\elena\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\elena\anaconda3\lib\site-packages (from pandas>=2.0.0->pyLDAvis) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\elena\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->pyLDAvis) (2.2.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\elena\anaconda3\lib\site-packages (from gensim->pyLDAvis) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\elena\anaconda3\lib\site-packages (from gensim->pyLDAvis) (2.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\elena\anaconda3\lib\site-packages (from jinja2->pyLDAvis) (2.1.1)
# Requirement already satisfied: pyfume in c:\users\elena\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim->pyLDAvis) (0.2.25)
# Requirement already satisfied: six>=1.5 in c:\users\elena\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.16.0)
# Requirement already satisfied: simpful in c:\users\elena\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (2.11.1)
# Requirement already satisfied: fst-pso in c:\users\elena\anaconda3\lib\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (1.8.1)
# Requirement already satisfied: miniful in c:\users\elena\anaconda3\lib\site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim->pyLDAvis) (0.0.6)

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
import pandas as pd


pyLDAvis.enable_notebook()
lda = LdaModel(corpus, num_topics=6, id2word=dictionary, passes=15)
vis = gensimvis.prepare(lda, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 7
#       3 import pandas as pd
#       6 pyLDAvis.enable_notebook()
# ----> 7 lda = LdaModel(corpus, num_topics=6, id2word=dictionary, passes=15)
#       8 vis = gensimvis.prepare(lda, corpus, dictionary)
#       9 pyLDAvis.display(vis)
#
# NameError: name 'LdaModel' is not defined

# %% [markdown]
# **Named Entity Recognition (NER).**
#
# NER - распознавание именованных сущностей, т.е. уникальных объектов в тексте - имена, названия стран, валюты, деньги, часто числительные и т.д.

# %%
import spacy
! python -m spacy download ru_core_news_sm
nlp_rus = spacy.load("ru_core_news_sm")

# %%
from spacy import displacy
doc = nlp_rus(kuprin_text[2400:3000])
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Амиров
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  без труда запоминает и пересказывает товарищам толково, точно, но суховато.<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Нельгин - фантазер
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . Его воображение неистощимо и чудовищно пышно. Еще до классного обучения, в малолетней группе, по вечерам, в часы, оставшиеся до ужина, когда наиболее прилежные мальчики плели по способу
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Фребеля
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  коврики из разноцветных бумажек, или расшивали шерстями выколотых на картоне попугаев, или клеили домики, или просто, без всякой мысли, измазав доску сплошь грифелем, разводили на ней при помощи намусленного пальца облака и макароны, -
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Нельгин
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  рассказывал своим мечтательным слушателям пестрые чудесны</div></span>

# %%
doc = nlp_rus(tolstoy_text[1500:2400])
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">нала &quot;Русский вестник&quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     М.Н. Каткова
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  в оглавлении и даже в объявлении не называть его сочинение романом: &quot;...для меня это очень важно, и потому очень прошу вас об этом&quot; (61, 67). Толстой мог бы обосновать свое определение жанра (&quot;книга&quot;) ссылкой на
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Гегеля
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , которого он внимательно перечитывал в годы работы над &quot;Войной и миром&quot;.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Гегель
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  называл книгой эпические произведения, связанные с &quot;целостным миром&quot; определенного народа и определенной эпохи. Книга, или &quot;самобытная эпопея&quot;, дает картину национального самосознания &quot;в нравственных устоях семейной жизни, в общественных условиях состояния войны и мира (курсив наш. - Э.Б.), в его потребностях, искусствах, обычаях, интересах...&quot;.5<br><br>     &quot;
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Анну Каренину
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# &quot; Толстой называл романом из современной жизни. В 1873 году, только еще начиная работу, он говорил
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Н.Н. Страхову
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# : &quot;...роман этот - именно роман (курсив наш. - Э.Б.), первый в моей жизни, очень
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     взя
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from textblob import TextBlob

# Функция для расчета настроений отдельных слов
def calculate_word_sentiments(text):
    blob = TextBlob(text)
    word_sentiments = []
    for word in blob.words:
        word_blob = TextBlob(word)
        word_sentiments.append((word, word_blob.sentiment.polarity, word_blob.sentiment.subjectivity))
    return word_sentiments

kuprin_word_sentiments = calculate_word_sentiments(kuprin_text)
tolstoy_word_sentiments = calculate_word_sentiments(tolstoy_text)

# Объединяем данные о настроениях обоих авторов
all_word_sentiments = kuprin_word_sentiments + tolstoy_word_sentiments

# Отфильтровываем слова для аннотации на графике
words_to_annotate = [sentiment for sentiment in all_word_sentiments if abs(sentiment[1]) > 0.1 and abs(sentiment[2]) > 0.1]

# Создаем scatter plot
plt.figure(figsize=(15, 10))
colors = [sentiment[1] for sentiment in all_word_sentiments]  # полярность
sizes = [sentiment[2] * 100 for sentiment in all_word_sentiments]  # субъективность

plt.scatter([sentiment[1] for sentiment in all_word_sentiments],
            [sentiment[2] for sentiment in all_word_sentiments],
            alpha=0.5, c=colors, cmap='RdYlGn', s=sizes)

# Аннотируем слова на графике
for sentiment in words_to_annotate:
    plt.annotate(sentiment[0], (sentiment[1], sentiment[2]), fontsize=8)

# Добавляем цветовую шкалу
plt.colorbar(label='Polarity')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.title('Sentiment Analysis of Russian Classical Literature')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Исходя из анализа тональности выше и этого графика, мы можем сделать вывод, что TextBlob не справляется с русским текстом, поэтому попробуем другой подход

# %%
# !pip install dostoevsky
# !python -m dostoevsky download fasttext-social-network-model
# Out:
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp310-cp310-linux_x86_64.whl size=4133804 sha256=904f98778489d7edfb438adb3dd0b0b3be7085744f46c5324591195b5eb0d3a8
#   Stored in directory: /root/.cache/pip/wheels/a5/13/75/f811c84a8ab36eedbaef977a6a58a98990e8e0f1967f98f394
# Successfully built fasttext
# Installing collected packages: razdel, fasttext, dostoevsky
# Successfully installed dostoevsky-0.6.0 fasttext-0.9.2 razdel-0.5.0

# %%
from dostoevsky.tokenization import RegexTokenizer
from dostoevsky.models import FastTextSocialNetworkModel

# Инициализируем токенизатор и модель
tokenizer = RegexTokenizer()
model = FastTextSocialNetworkModel(tokenizer=tokenizer)

kuprin_results = model.predict([kuprin_text], k=2)
tolstoy_results = model.predict([tolstoy_text], k=2)

# Выводим результаты
print(f"Sentiment Kuprin: {kuprin_results}")
print(f"Sentiment Tolstoy: {tolstoy_results}")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# Sentiment Kuprin: [{'negative': 0.287777841091156, 'skip': 0.22271016240119934}]
# Sentiment Tolstoy: [{'negative': 0.2689514458179474, 'neutral': 0.24509501457214355}]

# %% [markdown]
# Результаты анализа тональности для произведений Куприна и Толстого показывают, что оба текста имеют относительно высокие показатели негативной тональности. Однако, важно учитывать контекст использования модели Dostoevsky. Она была обучена на данных из социальных сетей, которые могут значительно отличаться от литературного языка.

# %% [markdown]
# создадим стековую гистограмму, где для каждого из 20 наиболее часто встречающихся слов будет показано, какое количество раз это слово встречается в каждом из произведений.

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Предположим, что 'kuprin_tokens' и 'tolstoy_tokens' - это ваши токены
kuprin_word_counts = Counter(kuprin_tokens)
tolstoy_word_counts = Counter(tolstoy_tokens)

# Выбираем 20 наиболее частых слов в обоих текстах
common_words = set([word for word, _ in kuprin_word_counts.most_common(20)] + [word for word, _ in tolstoy_word_counts.most_common(20)])

# Подготовка данных для стековой гистограммы
words = list(common_words)
kuprin_freqs = [kuprin_word_counts[word] for word in words]
tolstoy_freqs = [tolstoy_word_counts[word] for word in words]

# Создание графика
fig, ax = plt.subplots(figsize=(15, 8))
bar_width = 0.35
index = np.arange(len(words))

bars1 = plt.bar(index, kuprin_freqs, bar_width, label='Kuprin')
bars2 = plt.bar(index + bar_width, tolstoy_freqs, bar_width, label='Tolstoy')

plt.xlabel('Words')
plt.ylabel('Frequency')
plt.title('Word Frequency Comparison between Kuprin and Tolstoy')
plt.xticks(index + bar_width / 2, words, rotation=45, ha="right")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# еще раз про топик моделинг

# %%
from gensim.models import LdaModel

# Создание и обучение LDA модели
num_topics = 5
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, random_state=100, update_every=1, chunksize=100, passes=10, alpha='auto', per_word_topics=True)

# Вывод тем
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# WARNING:gensim.models.ldamodel:updated prior is not positive
# Topic: 0
# Words: 0.001*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.001*"рук" + 0.000*"александрович" + 0.000*"кит" + 0.000*"аркадьич" + 0.000*"дума" + 0.000*"алекс" + 0.000*"говор"
# Topic: 1
# Words: 0.001*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.001*"рук" + 0.000*"кит" + 0.000*"аркадьич" + 0.000*"брат" + 0.000*"дума" + 0.000*"глаз" + 0.000*"александрович"
# Topic: 2
# Words: 0.002*"левин" + 0.001*"ан" + 0.001*"вронск" + 0.001*"рук" + 0.001*"кит" + 0.001*"дума" + 0.001*"степа" + 0.001*"алекс" + 0.001*"александрович" + 0.001*"аркадьич"
# Topic: 3
# Words: 0.013*"левин" + 0.007*"ан" + 0.007*"вронск" + 0.005*"рук" + 0.005*"кит" + 0.005*"александрович" + 0.004*"аркадьич" + 0.004*"степа" + 0.004*"дума" + 0.004*"алекс"
# Topic: 4
# Words: 0.012*"нельгин" + 0.005*"мальчик" + 0.003*"рук" + 0.002*"юр" + 0.002*"голов" + 0.002*"амир" + 0.002*"всетак" + 0.002*"дам" + 0.002*"вод" + 0.002*"маленьк"

# %%
vis = gensimvis.prepare(lda_model, corpus, dictionary)
pyLDAvis.display(vis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 vis = gensimvis.prepare(lda_model, corpus, dictionary)
#       2 pyLDAvis.display(vis)
#
# NameError: name 'lda_model' is not defined

# %%
# Функция для извлечения топ N ключевых слов по абсолютному значению тональности
def extract_top_n_keywords(sentiments, sentences, n=10):
    keywords = []
    abs_sentiments = [abs(sentiment) for sentiment in sentiments]
    sorted_indices = sorted(range(len(abs_sentiments)), key=lambda k: abs_sentiments[k], reverse=True)[:n]
    for idx in sorted_indices:
        keywords.extend(sentences[idx].split())
    return keywords

# Извлечение топ 10 ключевых слов для произведения Куприна
kuprin_top_keywords = extract_top_n_keywords(kuprin_polarities, kuprin_sentences, n=10)
plot_wordcloud(kuprin_top_keywords)

# Извлечение топ 10 ключевых слов для произведения Толстого
tolstoy_top_keywords = extract_top_n_keywords(tolstoy_polarities, tolstoy_sentences, n=10)
plot_wordcloud(tolstoy_top_keywords)

# %%
# Функция для вычисления средней длины предложений
def calculate_average_sentence_length(sentences):
    sentence_lengths = [len(sentence.split()) for sentence in sentences]
    return sum(sentence_lengths) / len(sentences)

# Вычисление средней длины предложений для произведения Куприна
kuprin_avg_sentence_length = calculate_average_sentence_length(kuprin_sentences)
print("Average Sentence Length in Kuprin's Text:", kuprin_avg_sentence_length)

# Вычисление средней длины предложений для произведения Толстого
tolstoy_avg_sentence_length = calculate_average_sentence_length(tolstoy_sentences)
print("Average Sentence Length in Tolstoy's Text:", tolstoy_avg_sentence_length)
# Out:
# Average Sentence Length in Kuprin's Text: 14.836244541484715
# Average Sentence Length in Tolstoy's Text: 13.751116279069768

# %% [markdown]
# Средняя длина предложения в произведениях Куприна составляет примерно 14.84 слова, в то время как для Толстого этот показатель равен примерно 13.75 словам.
#
# Куприн, возможно, склоняется к более развёрнутому изложению идей в предложениях, что делает его тексты чуть более подробными на уровне отдельных предложений. Толстой, с другой стороны, использует чуть более сжатый стиль, что может способствовать динамике нарратива и доступности его текстов.

# %% [markdown]
# В ходе нашего исследования мы провели анализ двух выдающихся произведений русской классической литературы, написанных Александром Куприным и Львом Толстым. Используя различные методы обработки естественного языка и анализа данных, мы изучили лексическое наполнение, тематические различия, стилистические особенности и эмоциональную окраску текстов. Вот основные выводы нашего исследования:
#
# ## Лексические и тематические различия
# Облака слов и частотный анализ слов показали ключевые темы и мотивы, которые затрагивают оба автора в своих произведениях. Несмотря на некоторое пересечение в использовании лексики, каждый автор имеет уникальный набор слов, которые отражают специфику его творчества и фокус на определенных идеях.
#
# ## Стилистические особенности
# Анализ средней длины предложений выявил небольшие, но заметные различия в стилях написания Куприна и Толстого. Это указывает на различные подходы к структурированию текста и предпочтения в выражении мыслей, что может влиять на восприятие их произведений читателями.

# %% [markdown]
# # Общий вывод
# Исследование подчеркнуло богатство и глубину русской классической литературы через призму анализа произведений двух её выдающихся представителей. Несмотря на общую принадлежность к русской классике, произведения Куприна и Толстого демонстрируют уникальные стилистические, тематические и лексические особенности. Эти различия не только отражают индивидуальные литературные голоса авторов, но и предоставляют ценные инсайты в контекст эпохи, общественные настроения и личные взгляды авторов на обсуждаемые вопросы.
